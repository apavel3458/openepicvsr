# %%
import pandas as pd
import numpy as np
import plotly.express as px
from lib.DrugUtil import flatten, DrugUtil
import matplotlib.pyplot as plt

import plotly.express as px
from lib.FhirDataUtil import FhirDataUtil
from lib.CCSDataUtil import CCSDataUtil

def printmd(string):
    display(string)

# %load_ext autoreload
# %autoreload 2

pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_colwidth', None)

_fhir_conditions_file = "input/fhir_conditions_20221003.csv"
_fhir_medications_file = "input/fhir_medications_20221003.csv"
_fhir_medications_ref_file = "input/fhir_medications_references_20221003.csv"
_fhir_demographics_file = "input/fhir_demographics_20221113.csv"
_output_dir = 'output/'

_rxnorm_file = "input_static/RxTerms202203/RxTerms202203.txt"
_rxnorm_ingredients_file = "input_static/RxTerms202203/RxTermsIngredients202203.txt"
_rxclass_file = "input_static/_rxclass_2022-04-10.csv"

_ccs_demographics_file = "input/ccs_demographics.csv"
_ccs_medications_file = "input/ccs_medications.csv"
_ccs_conditions_file = "input/ccs_conditions.csv"

_pc_demographics_file = "input/pcornet/demographic_fhir.csv"
_pc_medications_file = "input/pcornet/med_adm_fhir.csv"

# %%
drugUtil = DrugUtil()
drugUtil.load(rxnorm_file=_rxnorm_file,
                        rxnorm_ingredients_file=_rxnorm_ingredients_file, 
                        rxclass_file=_rxclass_file)

fhirUtil = FhirDataUtil()
ccsUtil = CCSDataUtil(drugUtil)

fhirUtil.load_conditions(fhir_conditions_file=_fhir_conditions_file, remove_health_concerns=True)
fhirUtil.load_demographics(fhir_demographics_file=_fhir_demographics_file)

ccsUtil.load_conditions(ccs_conditions_file= _ccs_conditions_file)
ccsUtil.load_demographics(_ccs_demographics_file)
# Out:
# Reading rxclass file...
# Reading rxnorm file...
# RAW FHIR conditions: 52621
# FHIR conditions after pre-processing: 37248
# /app/lib/CCSDataUtil.py:13: DtypeWarning: Columns (5,6,11,12,13,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.conditions = pd.read_csv(ccs_conditions_file, delimiter=',')
# /app/lib/CCSDataUtil.py:75: DtypeWarning: Columns (11,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.demographics = pd.read_csv(ccs_demographics)
# Loaded CCS conditions records: 94735
# Loaded demographics file with entries:  98877

# %%
snomed = fhirUtil.conditions[fhirUtil.conditions['coding_system'] == 'SNOMED']
print(f'Number of snomeds: {len(snomed)}')
icd10 = fhirUtil.conditions[fhirUtil.conditions['coding_system'] == 'ICD10']
print(f'Number of ICD10s: {len(icd10)}')
# Out:
# Number of snomeds: 19850
# Number of ICD10s: 17398

# %%
pc_cond = pd.read_csv('input/pcornet/diagnosis_fhir.csv')
print('PCORNet Conditions: ', len(pc_cond))
pc_cond['dx_date_d'] = pd.to_datetime(pc_cond['dx_date'], format="%d%b%Y", errors="coerce").fillna(pd.to_datetime(pc_cond['admit_date'], format="%d%b%Y", errors="coerce"))
# fhir_enc_raw['start_d'] = pd.to_datetime(fhir_enc_raw['start'], format="%Y-%m-%dT%H:%M:%SZ", errors="coerce").fillna(pd.to_datetime(fhir_enc_raw['start'], format="%Y-%m-%d", errors="coerce"))

pc_demo = pd.read_csv('input/pcornet/demographic_fhir.csv')
# Out:
# PCORNet Conditions:  120358
# /tmp/ipykernel_290/1985917506.py:1: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   pc_cond = pd.read_csv('input/pcornet/diagnosis_fhir.csv')

# %%
xls = pd.ExcelFile('input/chart_review/Chart_Review1.0.xlsx')
cr_cond_raw = pd.read_excel(xls, 'Diagnostic Codes')
cr_demo = pd.read_excel(xls, 'users_to_query')
cr_cond_raw['date_entered_d'] = pd.to_datetime(cr_cond_raw['date_entered'], errors='coerce')
# Out:
# /usr/local/lib/python3.9/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)

# %%
fhir_cond = icd10
fhir_demo = fhirUtil.demographics
ccs_cond = ccsUtil.conditions
ccs_demo = ccsUtil.demographics

# %%
years = fhir_cond['recordeddate_d'].dt.year.value_counts().reset_index(name="Conditions")
plt.bar(years['index'], years['Conditions'])
plt.title('Conditions by year from FHIR')
plt.ylabel('N Unique conditions')
plt.show()
fhir_cond['recordeddate_d'].dropna().sort_values()
# Out:
# 8596    1975-01-01
# 28234   1989-01-01
# 8573    1990-01-01
# 8594    1990-01-01
# 12133   1992-12-02
#            ...
# 5867    2022-09-09
# 51607   2022-09-10
# 4516    2022-09-12
# 34529   2022-09-12
# 26888   2022-09-12
# Name: recordeddate_d, Length: 17255, dtype: datetime64[ns]

# %%
years = pc_cond['dx_date_d'].dt.year.value_counts().reset_index(name="Conditions")
plt.bar(years['index'], years['Conditions'])
plt.title('Conditions by year from PCORnet')
plt.ylabel('N Unique conditions')
plt.xlabel('year recorded')
plt.show()
pc_cond['dx_date_d'].dropna().sort_values()
# Out:
# 45920   2015-11-27
# 54983   2015-11-30
# 92781   2015-11-30
# 92863   2015-11-30
# 55074   2015-11-30
#            ...
# 33482   2022-04-01
# 71629   2022-04-01
# 27621   2022-04-01
# 85781   2022-04-01
# 85663   2022-04-01
# Name: dx_date_d, Length: 120310, dtype: datetime64[ns]

# %%
years = cr_cond['date_entered_d'].dt.year.value_counts().reset_index(name="Conditions")
plt.bar(years['index'], years['Conditions'])
plt.title('Conditions by year from PCORnet')
plt.ylabel('N Unique conditions')
plt.xlabel('year recorded')
plt.show()
# cr_cond['date_entered_d'].sort_values()

# %%
start_date = '2015-11-27' # datetime.date(2015,11,27)
end_date = '2022-04-01'

cr_cond = cr_cond_raw.copy()

print(f'Filtering for dates...')
print(f'Before (FHIR, PCORnet, Chart Review) ', len(fhir_cond), ' ', len(pc_cond), ' ', len(cr_cond))
fhir_cond = fhir_cond[fhir_cond['recordeddate'].between(start_date, end_date)]
pc_cond = pc_cond[pc_cond['dx_date_d'].between(start_date, end_date)]
cr_cond = cr_cond[~(cr_cond['date_entered_d'] < start_date)]
cr_cond = cr_cond[~(cr_cond['date_entered_d'] > end_date)]
# cr_cond = cr_cond[cr_cond['date_entered_d'].between(start_date, end_date)]
print(f'After (FHIR, PCORnet, Chart Review) ', len(fhir_cond), ' ', len(pc_cond), ' ', len(cr_cond))
# Out:
# Filtering for dates...
# Before (FHIR, PCORnet, Chart Review)  11614   120310   311
# After (FHIR, PCORnet, Chart Review)  11614   120310   284

# %%
cr_cond
# Out:
#      user_id diagnostic_code         date_entered           code_source  \
# 0     458871           M54.2  2016-03-27 00:00:00          Problem List
# 1     458871           F41.9  2016-03-27 00:00:00          Problem List
# 2     458871           Z97.5  2018-04-06 00:00:00          Problem List
# 3     458871           E66.3  2018-04-06 00:00:00          Problem List
# 4     458871           F41.9                  NaN  Past Medical History
# 5     458871           F32.A                  NaN  Past Medical History
# 6     458871           M54.2                  NaN  Past Medical History
# 10     35829          G56.00  2021-05-14 00:00:00          Problem List
# 11     35829           J34.2  2018-03-07 00:00:00          Problem List
# 12     35829           J34.3  2018-03-07 00:00:00          Problem List
# 13     35829          J34.89  2018-03-07 00:00:00          Problem List
# 15     35829          M70.51  2019-02-04 00:00:00          Problem List
# 16     35829           J30.9                  NaN  Past Medical History
# 17     35829           M71.9                  NaN  Past Medical History
# 18     35829           E78.5                  NaN  Past Medical History
# 19     35829          G56.03  2021-12-06 00:00:00      Chart Review Tab
# 20     35829          G56.01  2021-11-03 00:00:00      Chart Review Tab
# 21     35829          G56.03  2021-10-26 00:00:00      Chart Review Tab
# 22     35829           M71.9  2021-10-26 00:00:00      Chart Review Tab
# 23     35829           J30.9  2021-10-26 00:00:00      Chart Review Tab
# 24     35829           E78.5  2021-10-26 00:00:00      Chart Review Tab
# 25     35829          G56.02  2021-07-22 00:00:00      Chart Review Tab
# 26     35829          G56.02  2021-07-12 00:00:00      Chart Review Tab
# 27     35829          M54.12  2021-07-12 00:00:00      Chart Review Tab
# 28     35829          G56.02  2021-06-17 00:00:00      Chart Review Tab
# 29     35829          G56.00  2021-06-08 00:00:00      Chart Review Tab
# 30     35829           M71.9  2021-06-08 00:00:00      Chart Review Tab
# 31     35829           J30.9  2021-06-08 00:00:00      Chart Review Tab
# 32     35829           E78.5  2021-06-08 00:00:00      Chart Review Tab
# 33     35829          M54.12  2021-05-10 00:00:00      Chart Review Tab
# 34     35829         M79.602  2021-05-10 00:00:00      Chart Review Tab
# 35     35829          M54.12  2021-05-05 00:00:00      Chart Review Tab
# 36     35829         M79.602  2021-05-05 00:00:00      Chart Review Tab
# 37    477473             I38  2019-03-12 00:00:00          Problem List
# 39    477473           R00.1  2019-05-07 00:00:00          Problem List
# 42    477473           N40.0  2021-08-09 00:00:00          Problem List
# 43    477473           N39.0  2021-09-15 00:00:00          Problem List
# 44    477473           E78.5  2019-03-12 00:00:00          Problem List
# 45    477473          R97.20  2021-08-09 00:00:00          Problem List
# 46    477473         Z87.442  2021-09-21 00:00:00          Problem List
# 47    477473           I33.0                  NaN  Past Medical History
# 48    477473           N40.0                  NaN  Past Medical History
# 49    477473          B19.20                  NaN  Past Medical History
# 50    477473           E78.5                  NaN  Past Medical History
# 51    477473             I10                  NaN  Past Medical History
# 52    477473           J98.4                  NaN  Past Medical History
# 53    477473           N40.0                  NaN      Chart Review Tab
# 54    477473           N20.0                  NaN      Chart Review Tab
# 55    477473          R97.20                  NaN      Chart Review Tab
# 56    477473           N40.0                  NaN      Chart Review Tab
# 57    477473          N30.00                  NaN      Chart Review Tab
# 58    477473           R07.9                  NaN      Chart Review Tab
# 59    477473           R00.1                  NaN      Chart Review Tab
# 60    477473             I10                  NaN      Chart Review Tab
# 61    477473           E78.5                  NaN      Chart Review Tab
# 62    477473           N39.0                  NaN      Chart Review Tab
# 63    477473           N40.0                  NaN      Chart Review Tab
# 64    477473          R97.20                  NaN      Chart Review Tab
# 65    477473         Z87.442                  NaN      Chart Review Tab
# 66    477473        \tR97.20                  NaN      Chart Review Tab
# 67    477473         Z87.442                  NaN      Chart Review Tab
# 68    477473          Z86.69                  NaN      Chart Review Tab
# 69    477473           Z96.1                  NaN      Chart Review Tab
# 70    477473          Z86.69                  NaN      Chart Review Tab
# 71    477473          K74.69                  NaN      Chart Review Tab
# 72    477473          B19.20                  NaN      Chart Review Tab
# 73    477473           I33.0                  NaN      Chart Review Tab
# 74    477473           E78.5                  NaN      Chart Review Tab
# 75    477473             I10                  NaN      Chart Review Tab
# 77    462377           R04.0  2020-03-21 00:00:00          Problem List
# 78    462377             I10  2019-12-10 00:00:00          Problem List
# 79    462377           I72.0  2019-12-10 00:00:00          Problem List
# 80    462377           I47.1  2020-03-31 00:00:00          Problem List
# 81    462377           H53.9                  NaN          Problem List
# 82    462377          I67.89                  NaN  Past Medical History
# 83    462377          I48.91                  NaN  Past Medical History
# 84    462377           I67.1                  NaN  Past Medical History
# 85    462377          G61.81                  NaN  Past Medical History
# 86    462377           R51.9                  NaN  Past Medical History
# 87    462377             I10                  NaN  Past Medical History
# 88    462377          M54.50                  NaN  Past Medical History
# 89    462377             G35                  NaN  Past Medical History
# 90    462377           H46.9                  NaN  Past Medical History
# 91    462377           G83.9                  NaN  Past Medical History
# 92    462377           G98.8                  NaN  Past Medical History
# 93    462377             Z23  2021-02-04 00:00:00      Chart Review Tab
# 94    462377             Z23  2021-02-26 00:00:00      Chart Review Tab
# 95    462377             I10  2021-04-26 00:00:00      Chart Review Tab
# 96    462377          G61.81  2021-06-07 00:00:00      Chart Review Tab
# 97    462377          G61.81  2022-01-05 00:00:00      Chart Review Tab
# 98    462377           H46.9  2022-02-14 00:00:00      Chart Review Tab
# 99    454596         J45.909                  NaN  Past Medical History
# 100   454596           C80.1                 2014  Past Medical History
# 101   454596           F32.A                  NaN  Past Medical History
# 102   454596           E78.9                  NaN  Past Medical History
# 103   454596           E04.9                  NaN  Past Medical History
# 104   454596           Z87.2                  NaN  Past Medical History
# 105   454596         Z85.850                  NaN  Past Medical History
# 106   454596          Z87.42                  NaN  Past Medical History
# 107   454596          Z86.39                  NaN  Past Medical History
# 108   454596          Z86.59                  NaN  Past Medical History
# 109   454596           E07.9                  NaN  Past Medical History
# 110   454596         J45.909                  NaN  Past Medical History
# 111   454596          M54.16  2017-03-07 00:00:00          Problem List
# 112   454596          M51.16  2017-03-29 00:00:00          Problem List
# 113   454596          M51.26  2017-04-18 00:00:00          Problem List
# 114   454596         Z98.890  2017-06-20 00:00:00          Problem List
# 115   454596           D22.9  2021-09-20 00:00:00      Chart Review Tab
# 116   454596           L28.0  2021-09-20 00:00:00      Chart Review Tab
# 117   454596           B07.8  2021-09-20 00:00:00      Chart Review Tab
# 118   378622             I10  2020-03-03 00:00:00          Problem List
# 119   378622           I25.9  2020-03-03 00:00:00          Problem List
# 121   378622           M10.9                  NaN          Problem List
# 122   378622           G47.9                  NaN          Problem List
# 123   378622          C44.91                  NaN  Past Medical History
# 124   378622           M10.9                  NaN  Past Medical History
# 125   378622           I51.9                  NaN  Past Medical History
# 126   378622             I10                  NaN  Past Medical History
# 127   378622           M79.9  2021-01-01 00:00:00  Past Medical History
# 128   378622           G47.9                  NaN  Past Medical History
# 129   378622             Z23  2021-02-01 00:00:00      Chart Review Tab
# 130   378622             Z23  2021-03-01 00:00:00      Chart Review Tab
# 131   378622             I10  2021-03-16 00:00:00      Chart Review Tab
# 132   378622           I25.9  2021-03-16 00:00:00      Chart Review Tab
# 133   378622          Z11.59  2021-03-16 00:00:00      Chart Review Tab
# 134   378622             I10  2021-04-12 00:00:00      Chart Review Tab
# 135   378622          I25.10  2021-04-12 00:00:00      Chart Review Tab
# 136   378622             R17  2021-04-12 00:00:00      Chart Review Tab
# 137   378622           D22.5  2021-04-19 00:00:00      Chart Review Tab
# 138   378622           L21.9  2021-04-19 00:00:00      Chart Review Tab
# 139   378622           L57.0  2021-04-19 00:00:00      Chart Review Tab
# 140   378622           L81.4  2021-04-19 00:00:00      Chart Review Tab
# 141   378622         Z85.828  2021-04-19 00:00:00      Chart Review Tab
# 142   378622           L21.8  2021-04-19 00:00:00      Chart Review Tab
# 143   378622           L82.1  2021-04-19 00:00:00      Chart Review Tab
# 144   378622             I10  2021-05-19 00:00:00      Chart Review Tab
# 145   378622             I10  2021-06-21 00:00:00      Chart Review Tab
# 146   378622             I10  2021-08-29 00:00:00      Chart Review Tab
# 147   378622             I10  2021-11-17 00:00:00      Chart Review Tab
# 148   378622           K63.5  2021-12-01 00:00:00      Chart Review Tab
# 149   378622          M54.50  2021-12-10 00:00:00      Chart Review Tab
# 150   378622          M54.50  2022-02-28 00:00:00      Chart Review Tab
# 151   378622             I10  2022-03-09 00:00:00      Chart Review Tab
# 152   457587             G35  2018-06-05 00:00:00          Problem List
# 153   457587          G47.26  2018-06-05 00:00:00          Problem List
# 154   457587          G47.00  2018-06-05 00:00:00          Problem List
# 155   457587           K90.0                  NaN  Past Medical History
# 156   457587             G35                  NaN  Past Medical History
# 157   457587          I73.00                  NaN  Past Medical History
# 158   457587         Z79.899  2021-02-24 00:00:00      Chart Review Tab
# 159   457587        D72.810   2021-02-24 00:00:00      Chart Review Tab
# 160   457587             G35  2021-02-24 00:00:00      Chart Review Tab
# 161   457587             G35  2021-05-06 00:00:00      Chart Review Tab
# 162   457587           Z02.9  2021-05-06 00:00:00      Chart Review Tab
# 163   457587             G35  2021-05-25 00:00:00      Chart Review Tab
# 164   457587          R53.83  2021-05-25 00:00:00      Chart Review Tab
# 165   457587         Z79.899  2021-07-01 00:00:00      Chart Review Tab
# 166   457587         D72.810  2021-07-01 00:00:00      Chart Review Tab
# 167   457587             G35  2021-07-01 00:00:00      Chart Review Tab
# 168   457587             G35  2021-09-13 00:00:00      Chart Review Tab
# 169   457587             G35  2021-09-17 00:00:00      Chart Review Tab
# 170   457587             G35  2021-10-15 00:00:00      Chart Review Tab
# 171   457587             G35  2021-10-15 00:00:00      Chart Review Tab
# 172   457587             G35  2021-02-15 00:00:00      Chart Review Tab
# 173   457587         D72.810  2021-02-15 00:00:00      Chart Review Tab
# 174   457587         Z79.899  2021-02-15 00:00:00      Chart Review Tab
# 175   465182           J34.3  2017-09-22 00:00:00          Problem List
# 176   465182        T78.40XA                  NaN          Problem List
# 177   465182          M19.90                  NaN          Problem List
# 178   465182           J32.9                  NaN          Problem List
# 179   465182          K59.00                  NaN          Problem List
# 180   465182           F32.A                  NaN          Problem List
# 181   465182          E78.00                  NaN          Problem List
# 182   465182             I10                  NaN          Problem List
# 183   465182        V29.9XXA                  NaN          Problem List
# 184   465182           J34.9                  NaN          Problem List
# 185   465182             Z23                  NaN          Problem List
# 189   458578         M67.442  2021-09-08 00:00:00          Problem List
# 190   458578        T78.40XA                  NaN  Past Medical History
# 191   458578         J45.909                  NaN  Past Medical History
# 192   458578           F32.A                  NaN  Past Medical History
# 193   458578           J18.9                  NaN  Past Medical History
# 194   458578          G47.30                  NaN  Past Medical History
# 195   458578             A64                  NaN  Past Medical History
# 196   458578          M67.80  2021-08-31 00:00:00      Chart Review Tab
# 197   458578         M67.442  2021-09-14 00:00:00      Chart Review Tab
# 198   458578          M67.80  2021-09-23 00:00:00      Chart Review Tab
# 199   458578          M67.80  2021-10-22 00:00:00      Chart Review Tab
# 200   481303         C50.912  2020-05-21 00:00:00          Problem List
# 201   481303           C77.3  2020-05-21 00:00:00          Problem List
# 202   481303         C50.912                  NaN  Past Medical History
# 203   481303           C77.3                  NaN  Past Medical History
# 206   433846          K40.90  2016-01-20 00:00:00          Problem List
# 207   433846         J45.909                  NaN  Past Medical History
# 208   433846           K63.5                  NaN  Past Medical History
# 209   433846           K64.9                  NaN  Past Medical History
# 210   433846           K63.9                  NaN  Past Medical History
# 211   433846          K40.90                  NaN  Past Medical History
# 212   433846           J33.9                  NaN  Past Medical History
# 213   433846             C61                  NaN  Past Medical History
# 214   433846             C61                  NaN  Past Medical History
# 215   433846           N40.2                  NaN  Past Medical History
# 216   433846           J30.2                  NaN  Past Medical History
# 217   433846           L98.9                  NaN  Past Medical History
# 218   433846          R97.20  2021-06-11 00:00:00      Chart Review Tab
# 219   433846             C61  2021-06-15 00:00:00      Chart Review Tab
# 220   433846             C61  2021-07-01 00:00:00      Chart Review Tab
# 221   480918           K21.9                  NaN  Past Medical History
# 222   462421           K21.9  2019-09-09 00:00:00          Problem List
# 223   462421          C44.91  2021-03-11 00:00:00          Problem List
# 224   462421          C44.90                  NaN  Past Medical History
# 225   462421           Z41.1  2021-03-11 00:00:00      Chart Review Tab
# 226   457363          G89.29  2016-01-13 00:00:00          Problem List
# 227   457363           M79.2  2021-12-07 00:00:00          Problem List
# 231   457363         J45.909  2016-02-01 00:00:00          Problem List
# 233   457363             I10  2017-06-05 00:00:00          Problem List
# 234   457363           R23.2  2018-09-05 00:00:00          Problem List
# 235   457363           E66.9  2016-02-01 00:00:00          Problem List
# 236   457363           E55.9  2016-02-01 00:00:00          Problem List
# 237   457363           N73.6  2022-01-04 00:00:00          Problem List
# 238   457363           D25.1  2022-01-04 00:00:00          Problem List
# 239   457363           N95.0  2021-09-14 00:00:00          Problem List
# 240   457363          M24.80  2016-05-03 00:00:00          Problem List
# 241   457363           M51.9  2016-05-03 00:00:00          Problem List
# 242   457363         M47.812  2021-10-26 00:00:00          Problem List
# 243   457363         M47.816  2021-09-16 00:00:00          Problem List
# 244   457363          Q79.62  2016-05-09 00:00:00          Problem List
# 247   457363           F90.9  2016-01-13 00:00:00          Problem List
# 248   457363         Z79.891  2021-09-16 00:00:00          Problem List
# 250   457363         Z01.818                  NaN          Problem List
# 251   457363           N73.6  2022-01-04 00:00:00  Past Medical History
# 252   457363        T78.40XA                  NaN  Past Medical History
# 253   457363           F41.9                  NaN  Past Medical History
# 254   457363          M19.90                  NaN  Past Medical History
# 255   457363         J45.909  2016-02-01 00:00:00  Past Medical History
# 256   457363           F90.9  2016-01-13 00:00:00  Past Medical History
# 257   457363          F11.20                  NaN  Past Medical History
# 259   457363          G89.29  2016-01-13 00:00:00  Past Medical History
# 260   457363         Z79.891  2021-09-16 00:00:00  Past Medical History
# 262   457363           F32.A                  NaN  Past Medical History
# 263   457363           E11.9                  NaN  Past Medical History
# 264   457363           M51.9  2016-05-03 00:00:00  Past Medical History
# 265   457363          Q79.62  2016-05-09 00:00:00  Past Medical History
# 266   457363             I10  2017-06-05 00:00:00  Past Medical History
# 267   457363           D25.1  2022-01-04 00:00:00  Past Medical History
# 268   457363          M24.80  2016-05-03 00:00:00  Past Medical History
# 269   457363           K21.9                 2010  Past Medical History
# 270   457363           R51.9                 1995  Past Medical History
# 271   457363           R23.2  2018-09-05 00:00:00  Past Medical History
# 273   457363           E03.9                  NaN  Past Medical History
# 274   457363          M25.50                 2003  Past Medical History
# 275   457363          M54.50                 2003  Past Medical History
# 277   457363           M79.2  2021-12-07 00:00:00  Past Medical History
# 278   457363           E66.9  2016-02-01 00:00:00  Past Medical History
# 280   457363          M19.90                  NaN  Past Medical History
# 282   457363           N95.0  2021-09-14 00:00:00  Past Medical History
# 283   457363           M41.9                  NaN  Past Medical History
# 284   457363           J34.9                  NaN  Past Medical History
# 285   457363           G47.9                  NaN  Past Medical History
# 286   457363          M48.00                  NaN  Past Medical History
# 287   457363          M43.10                  NaN  Past Medical History
# 288   457363         M47.812  2021-10-26 00:00:00  Past Medical History
# 289   457363         M47.816  2021-09-16 00:00:00  Past Medical History
# 290   457363           E55.9  2016-02-01 00:00:00  Past Medical History
# 291   457363             Z23  2021-02-25 00:00:00      Chart Review Tab
# 292   457363          M54.12  2021-08-13 00:00:00      Chart Review Tab
# 293   457363          M48.02  2021-08-13 00:00:00      Chart Review Tab
# 294   457363           M41.9  2021-08-13 00:00:00      Chart Review Tab
# 295   457363          M51.36  2021-08-13 00:00:00      Chart Review Tab
# 296   457363          M48.02  2021-09-20 00:00:00      Chart Review Tab
# 297   457363          M50.30  2021-09-20 00:00:00      Chart Review Tab
# 298   457363           M41.9  2021-09-20 00:00:00      Chart Review Tab
# 299   457363          M54.12  2021-09-20 00:00:00      Chart Review Tab
# 300   457363          R06.00  2021-10-08 00:00:00      Chart Review Tab
# 301   457363          M54.12  2021-10-08 00:00:00      Chart Review Tab
# 302   457363          Z48.89  2022-02-10 00:00:00      Chart Review Tab
# 303   457363          M50.30  2022-02-18 00:00:00      Chart Review Tab
# 304   457363         Z98.890  2022-02-18 00:00:00      Chart Review Tab
# 305   457363          M48.02  2022-02-22 00:00:00      Chart Review Tab
# 306   457363          M54.12  2022-02-22 00:00:00      Chart Review Tab
# 307   457363         Z98.890  2022-02-22 00:00:00      Chart Review Tab
# 308   457363          I65.09  2022-03-01 00:00:00      Chart Review Tab
# 309   457363          M54.12  2022-03-01 00:00:00      Chart Review Tab
# 310   457363          M54.12  2022-03-29 00:00:00      Chart Review Tab
#
#                                                                                                      Notes:  \
# 0                                                                                                       NaN
# 1                                                                                                       NaN
# 2                                                                                                       NaN
# 3                                                                                                       NaN
# 4                                                                                                       NaN
# 5                                                                                                       NaN
# 6                                                                                                       NaN
# 10                                                                                                      NaN
# 11                                                                                                      NaN
# 12                                                                                                      NaN
# 13                                                                                                      NaN
# 15                                                                                                      NaN
# 16                                                                                                      NaN
# 17                                                                                                      NaN
# 18                                                                                                      NaN
# 19                                                                      12/6/21 Video Visit, under Visit Dx
# 20                                                                     11/3/21 office visit, under visit Dx
# 21                                                              10/26/21 Anesthia event, under free text Dx
# 22                                 10/26/21 Surgery, notes under Medical History under Past Medical History
# 23                                 10/26/21 Surgery, notes under Medical History under Past Medical History
# 24                                 10/26/21 Surgery, notes under Medical History under Past Medical History
# 25                                                                            7/22/21 Orders Only, under Dx
# 26                                                                      7/12/21 Video Visit, under Visit Dx
# 27                                                                      7/12/21 Video Visit, under Visit Dx
# 28                                                                     6/17/21 Office visit, under Visit Dx
# 29                                                         6/8/21 Anesthia, notes under Free Text Diagnosis
# 30                                   6/8/21 Surgery, notes under Medical History under Past Medical History
# 31                                   6/8/21 Surgery, notes under Medical History under Past Medical History
# 32                                   6/8/21 Surgery, notes under Medical History under Past Medical History
# 33                                                                     5/10/21 office visit, under Visit Dx
# 34                                                                     5/10/21 office visit, under visit Dx
# 35                                                                       5/5/21 Video Visit, under Visit Dx
# 36                                                                       5/5/21 Video Visit, under visit Dx
# 37                                                                         Noted: 3/12/19, Edited: 3/8/2022
# 39                                                                                            Noted: 5/7/19
# 42                                                                           Noted: 8/9/21; Edited: 9/21/21
# 43                                                                                           Noted: 9/15/21
# 44                                                                           Noted: 3/12/19; Edited: 3/8/22
# 45                                                                                            Noted: 8/9/21
# 46                                                                                           Noted: 9/21/21
# 47                                                                                                      NaN
# 48                                                                                                      NaN
# 49                                                                                                      NaN
# 50                                                                                                      NaN
# 51                                                                                                      NaN
# 52                                                                                                      NaN
# 53                                                                             7/7/21 Orders Only, under Dx
# 54                                                                             7/7/21 Orders Only, under Dx
# 55                                                                      8/10/21 Video Visit, under Visit Dx
# 56                                                                      8/10/21 Video Visit, under Visit Dx
# 57                                                                            8/26/21 Orders Only, under Dx
# 58                                                                     9/16/21 Office Visit, under Visit Dx
# 59                                                                     9/16/21 Office Visit, under Visit Dx
# 60                                                                     9/16/21 Office Visit, under Visit Dx
# 61                                                                     9/16/21 Office Visit, under Visit Dx
# 62                                                                      9/21/21 Video Visit, under Visit Dx
# 63                                                                      9/21/21 Video Visit, under Visit Dx
# 64                                                                      9/21/21 Video Visit, under Visit Dx
# 65                                                                      9/21/21 Video Visit, under Visit Dx
# 66                                                                     10/22/21 Video Visit, under Visit Dx
# 67                                                                     12/23/21 Video Visit, under Visit dx
# 68                            2/10/22 Office Visit, under Visit Dx listed a "History of retinal detachment"
# 69                                                                    2/10/22 Office Visit, under Visit Dx
# 70                      2/10/22 Ophthalmology Diag, under Visit Dx listed a "History of retinal detachment"
# 71                                                                      2/14/22 Video Visit, under Visit Dx
# 72                                                                      2/14/22 Video Visit, under Visit Dx
# 73                                                                       3/8/22 Video Visit, under Visit Dx
# 74                                                                       3/8/22 Video Visit, under Visit Dx
# 75                                                                       3/8/22 Video Visit, under Visit Dx
# 77                                                                                         Noted: 3/21/2020
# 78                                                                                        Noted: 12/10/2019
# 79                                                                                        Noted: 12/10/2019
# 80                                                                                         Noted: 3/31/2020
# 81                                                                                                      NaN
# 82                                                                                                      NaN
# 83                                                                                                      NaN
# 84                                                                                                      NaN
# 85                                                                                                      NaN
# 86                                                                                                      NaN
# 87                                                                                                      NaN
# 88                                                                                                      NaN
# 89                                                                                                      NaN
# 90                                                                                                      NaN
# 91                                                                                                      NaN
# 92                                                                                                      NaN
# 93                                                                      2/4/21 Immunization, under visit Dx
# 94                                                                     2/26/21 Immunization, under visit Dx
# 95                                                                  4/26/21 Patient Message, under visit Dx
# 96                                                                      6/7/21 Office Visit, under visit Dx
# 97                                                                             1/5/22 Orders only, under Dx
# 98                                                                      2/14/22 Video Visit, under Visit Dx
# 99                                                                                                      NaN
# 100                                                                                   only year was entered
# 101                                                                                                     NaN
# 102                                                                                                     NaN
# 103                                                                                                     NaN
# 104                                                                                                     NaN
# 105                                                                                                     NaN
# 106                                                                                                     NaN
# 107                                                                                                     NaN
# 108                                                                                                     NaN
# 109                                                                                                     NaN
# 110                                                                                                     NaN
# 111                                                                                                     NaN
# 112                                                                                                     NaN
# 113                                                                                                     NaN
# 114                                                                                                     NaN
# 115                                                                    9/20/21 Office visit, under visit Dx
# 116                                                                    9/20/21 Office visit, under visit Dx
# 117                                                                    9/20/21 Office visit, under visit Dx
# 118                                                                                                     NaN
# 119                                                                                                     NaN
# 121                                                                                                     NaN
# 122                                                                                                     NaN
# 123                                                                                                     NaN
# 124                                                                                                     NaN
# 125                                                                                                     NaN
# 126                                                                                                     NaN
# 127                                                                                                     NaN
# 128                                                                                                     NaN
# 129                                                                     2/1/21 Immunization, under Visit Dx
# 130                                                                     3/1/21 Immunization, under Visit Dx
# 131                                                                 3/16/21 Patient Message, under visit Dx
# 132                                                                 3/16/21 Patient Message, under visit Dx
# 133                                                                 3/16/21 Patient Message, under visit Dx
# 134                                                                    4/12/21 Office Visit, under visit Dx
# 135                                                                    4/12/21 Office Visit, under visit Dx
# 136                                                                    4/12/21 Office Visit, under visit Dx
# 137                                                                    4/19/21 Office Visit, under Visit Dx
# 138                                                                    4/19/21 Office Visit, under Visit Dx
# 139                                                                    4/19/21 Office Visit, under Visit Dx
# 140                                                                    4/19/21 Office Visit, under Visit Dx
# 141                                                                    4/19/21 Office Visit, under Visit Dx
# 142                                                                    4/19/21 Office Visit, under Visit Dx
# 143                                                                    4/19/21 Office Visit, under Visit Dx
# 144                                                                 5/19/21 Patient Message, under visit Dx
# 145                                                                 6/21/21 Patient Message, under visit Dx
# 146                                                                 8/29/21 Patient Message, under visit Dx
# 147                                                                11/17/21 Patient Message, under visit Dx
# 148                                                                 12/1/21 Patient Message, under visit Dx
# 149                                                                   12/10/21 Office Visit, under visit Dx
# 150                                                                 2/28/22 Patient Message, under visit Dx
# 151                                                                  3/9/22 Patient Message, under visit Dx
# 152                                                                                                     NaN
# 153                                                                                                     NaN
# 154                                                                                                     NaN
# 155                                                                                                     NaN
# 156                                                                                                     NaN
# 157                                                                                                     NaN
# 158                                                                           2/24/21 Orders only, under Dx
# 159                                                                           2/24/21 Orders only, under Dx
# 160                                                                           2/24/21 Orders only, under Dx
# 161                                                                          5/6/21 E-visit, under visit Dx
# 162                                                                          5/6/21 E-visit, under visit Dx
# 163                                                                     5/25/21 Video visit, under visit Dx
# 164                                                                     5/25/21 Video visit, under visit Dx
# 165                                                                            7/1/21 Orders only, under Dx
# 166                                                                            7/1/21 Orders only, under Dx
# 167                                                                            7/1/21 Orders only, under Dx
# 168                                                                           9/13/21 Orders only, under Dx
# 169                                                                       9/17/21 Telephone, under visit Dx
# 170                                             10/15/21 MR Brain with and without Contrast, under visit Dx
# 171                                                  10/15/21 MR Cervical spine with and without Contrast,
# 172                                                                     2/15/21 Video visit, under visit Dx
# 173                                                                     2/15/21 Video visit, under visit Dx
# 174                                                                     2/15/21 Video visit, under visit Dx
# 175                                                                                                     NaN
# 176                                                                                                     NaN
# 177                                                                                                     NaN
# 178                                                                                                     NaN
# 179                                                                                                     NaN
# 180                                                                                                     NaN
# 181                                                                                                     NaN
# 182                                                                                                     NaN
# 183                                                                                   Free text: 2011, 2005
# 184                                                                                                     NaN
# 185                                                                                    12/2/21 Immunization
# 189                                                                                                     NaN
# 190                                                                                                     NaN
# 191                                                                                                     NaN
# 192                                                                                                     NaN
# 193                                                                                                     NaN
# 194                                                                                                     NaN
# 195                                                                                                     NaN
# 196                                                                    8/31/21 Office Visit, under visit Dx
# 197                                              9/14/21 Admission (Discharge), under Hospital Problem List
# 198                                                                    9/23/21 Office Visit, under visit Dx
# 199                                                                    10/22/21 Video Visit, under Visit Dx
# 200               This and the C77.3 entry were grouped together as one entry in the EHR: "C50.912, C77.3")
# 201             This and the C50.912 entry were grouped together as one entry in the EHR: "C50.912, C77.3")
# 202               This and the C77.3 entry were grouped together as one entry in the EHR: "C50.912, C77.3")
# 203             This and the C50.912 entry were grouped together as one entry in the EHR: "C50.912, C77.3")
# 206                                                                                                     NaN
# 207                                                                                                     NaN
# 208                                                                                                    2012
# 209                                                                                                    2000
# 210                                                                                                    2012
# 211                                                                                       Comment: Nov 2014
# 212                                                                                                     NaN
# 213                                                                                                     NaN
# 214                                                                                                     NaN
# 215                                                                                                     NaN
# 216                                                                                                     NaN
# 217                                                                                                     NaN
# 218                                                                           6/11/21 Orders Only, under Dx
# 219                                           6/15/21 MR Prostate with and without Contrast, under visit Dx
# 220                                                                      7/1/21 Video Visit, under visit Dx
# 221                                                                                                     NaN
# 222                                                                                                     NaN
# 223                                                                                                     NaN
# 224                                                                                                     NaN
# 225                                                                    3/11/21 Office Visit, under visit Dx
# 226                                                                                                     NaN
# 227                                                                                                     NaN
# 231                                                                                                     NaN
# 233                                                                                                     NaN
# 234                                                                                                     NaN
# 235                                                                                                     NaN
# 236                                                                                                     NaN
# 237                                                                                                     NaN
# 238                                                                                                     NaN
# 239                                                                                                     NaN
# 240                                                                                                     NaN
# 241                                                                                                     NaN
# 242                                                                                                     NaN
# 243                                                                                                     NaN
# 244                                                                                                     NaN
# 247                                                                                                     NaN
# 248                                                                                                     NaN
# 250                                                                                                     NaN
# 251                                                                                                     NaN
# 252                                                                                    Free text date: 1980
# 253                                                                                              date: 1984
# 254                                                                                                     NaN
# 255                                                                                                     NaN
# 256                                                                                                     NaN
# 257                                                                                                     NaN
# 259                                                                                                     NaN
# 260                                                                                                     NaN
# 262                                                                                              date: 1984
# 263                                                                                                     NaN
# 264                                                                                                     NaN
# 265                                                                                                     NaN
# 266                                                                                                     NaN
# 267                                                                                                     NaN
# 268                                                                                                     NaN
# 269                                                                                                     NaN
# 270                                                                                              date: 1995
# 271                                                                                                     NaN
# 273                                                                                                     NaN
# 274                                                                                              date: 2003
# 275                                                                                              date: 2003
# 277                                                                                                     NaN
# 278                                                                                                     NaN
# 280                                                                                                     NaN
# 282                                                                                                     NaN
# 283                                                                                         Free text: 1981
# 284                                                                                                     NaN
# 285                                                                                        Free text: 1990s
# 286                                                                                                     NaN
# 287                                                                                                     NaN
# 288                                                                                                     NaN
# 289                                                                                                     NaN
# 290                                                                                                     NaN
# 291                                                                    2/25/21 Immunization, under visit Dx
# 292                                                                     8/13/21 Video Visit, under visit Dx
# 293                                                                     8/13/21 Video Visit, under visit Dx
# 294                                                                     8/13/21 Video Visit, under visit Dx
# 295                                                                     8/13/21 Video Visit, under visit Dx
# 296                                                                     9/20/21 Video Visit, under visit Dx
# 297                                                                     9/20/21 Video Visit, under visit Dx
# 298                                                                     9/20/21 Video Visit, under visit Dx
# 299                                                                     9/20/21 Video Visit, under visit Dx
# 300                                                       10/8/21 CT Chest without Contrast, under visit Dx
# 301                                                              10/8/21 CT Cervical Spine without Contrast
# 302                                                                    2/10/22 Office Visit, under visit Dx
# 303                                                                           2/18/22 Orders Only, under Dx
# 304                                                                           2/18/22 Orders Only, under Dx
# 305                                                                    2/22/22 Office Visit, under visit Dx
# 306                                                                    2/22/22 Office Visit, under visit Dx
# 307                                                                    2/22/22 Office Visit, under visit Dx
# 308                                                                      3/1/22 Video Visit, under visit Dx
# 309                                                                            3/1/22 Orders Only, under Dx
# 310  3/29/22 CT Angiogram Brain/Neck for Stroke (includes 3D Post-Processing and Perfusion), under visit Dx
#
#     date_entered_d
# 0       2016-03-27
# 1       2016-03-27
# 2       2018-04-06
# 3       2018-04-06
# 4              NaT
# 5              NaT
# 6              NaT
# 10      2021-05-14
# 11      2018-03-07
# 12      2018-03-07
# 13      2018-03-07
# 15      2019-02-04
# 16             NaT
# 17             NaT
# 18             NaT
# 19      2021-12-06
# 20      2021-11-03
# 21      2021-10-26
# 22      2021-10-26
# 23      2021-10-26
# 24      2021-10-26
# 25      2021-07-22
# 26      2021-07-12
# 27      2021-07-12
# 28      2021-06-17
# 29      2021-06-08
# 30      2021-06-08
# 31      2021-06-08
# 32      2021-06-08
# 33      2021-05-10
# 34      2021-05-10
# 35      2021-05-05
# 36      2021-05-05
# 37      2019-03-12
# 39      2019-05-07
# 42      2021-08-09
# 43      2021-09-15
# 44      2019-03-12
# 45      2021-08-09
# 46      2021-09-21
# 47             NaT
# 48             NaT
# 49             NaT
# 50             NaT
# 51             NaT
# 52             NaT
# 53             NaT
# 54             NaT
# 55             NaT
# 56             NaT
# 57             NaT
# 58             NaT
# 59             NaT
# 60             NaT
# 61             NaT
# 62             NaT
# 63             NaT
# 64             NaT
# 65             NaT
# 66             NaT
# 67             NaT
# 68             NaT
# 69             NaT
# 70             NaT
# 71             NaT
# 72             NaT
# 73             NaT
# 74             NaT
# 75             NaT
# 77      2020-03-21
# 78      2019-12-10
# 79      2019-12-10
# 80      2020-03-31
# 81             NaT
# 82             NaT
# 83             NaT
# 84             NaT
# 85             NaT
# 86             NaT
# 87             NaT
# 88             NaT
# 89             NaT
# 90             NaT
# 91             NaT
# 92             NaT
# 93      2021-02-04
# 94      2021-02-26
# 95      2021-04-26
# 96      2021-06-07
# 97      2022-01-05
# 98      2022-02-14
# 99             NaT
# 100            NaT
# 101            NaT
# 102            NaT
# 103            NaT
# 104            NaT
# 105            NaT
# 106            NaT
# 107            NaT
# 108            NaT
# 109            NaT
# 110            NaT
# 111     2017-03-07
# 112     2017-03-29
# 113     2017-04-18
# 114     2017-06-20
# 115     2021-09-20
# 116     2021-09-20
# 117     2021-09-20
# 118     2020-03-03
# 119     2020-03-03
# 121            NaT
# 122            NaT
# 123            NaT
# 124            NaT
# 125            NaT
# 126            NaT
# 127     2021-01-01
# 128            NaT
# 129     2021-02-01
# 130     2021-03-01
# 131     2021-03-16
# 132     2021-03-16
# 133     2021-03-16
# 134     2021-04-12
# 135     2021-04-12
# 136     2021-04-12
# 137     2021-04-19
# 138     2021-04-19
# 139     2021-04-19
# 140     2021-04-19
# 141     2021-04-19
# 142     2021-04-19
# 143     2021-04-19
# 144     2021-05-19
# 145     2021-06-21
# 146     2021-08-29
# 147     2021-11-17
# 148     2021-12-01
# 149     2021-12-10
# 150     2022-02-28
# 151     2022-03-09
# 152     2018-06-05
# 153     2018-06-05
# 154     2018-06-05
# 155            NaT
# 156            NaT
# 157            NaT
# 158     2021-02-24
# 159     2021-02-24
# 160     2021-02-24
# 161     2021-05-06
# 162     2021-05-06
# 163     2021-05-25
# 164     2021-05-25
# 165     2021-07-01
# 166     2021-07-01
# 167     2021-07-01
# 168     2021-09-13
# 169     2021-09-17
# 170     2021-10-15
# 171     2021-10-15
# 172     2021-02-15
# 173     2021-02-15
# 174     2021-02-15
# 175     2017-09-22
# 176            NaT
# 177            NaT
# 178            NaT
# 179            NaT
# 180            NaT
# 181            NaT
# 182            NaT
# 183            NaT
# 184            NaT
# 185            NaT
# 189     2021-09-08
# 190            NaT
# 191            NaT
# 192            NaT
# 193            NaT
# 194            NaT
# 195            NaT
# 196     2021-08-31
# 197     2021-09-14
# 198     2021-09-23
# 199     2021-10-22
# 200     2020-05-21
# 201     2020-05-21
# 202            NaT
# 203            NaT
# 206     2016-01-20
# 207            NaT
# 208            NaT
# 209            NaT
# 210            NaT
# 211            NaT
# 212            NaT
# 213            NaT
# 214            NaT
# 215            NaT
# 216            NaT
# 217            NaT
# 218     2021-06-11
# 219     2021-06-15
# 220     2021-07-01
# 221            NaT
# 222     2019-09-09
# 223     2021-03-11
# 224            NaT
# 225     2021-03-11
# 226     2016-01-13
# 227     2021-12-07
# 231     2016-02-01
# 233     2017-06-05
# 234     2018-09-05
# 235     2016-02-01
# 236     2016-02-01
# 237     2022-01-04
# 238     2022-01-04
# 239     2021-09-14
# 240     2016-05-03
# 241     2016-05-03
# 242     2021-10-26
# 243     2021-09-16
# 244     2016-05-09
# 247     2016-01-13
# 248     2021-09-16
# 250            NaT
# 251     2022-01-04
# 252            NaT
# 253            NaT
# 254            NaT
# 255     2016-02-01
# 256     2016-01-13
# 257            NaT
# 259     2016-01-13
# 260     2021-09-16
# 262            NaT
# 263            NaT
# 264     2016-05-03
# 265     2016-05-09
# 266     2017-06-05
# 267     2022-01-04
# 268     2016-05-03
# 269            NaT
# 270            NaT
# 271     2018-09-05
# 273            NaT
# 274            NaT
# 275            NaT
# 277     2021-12-07
# 278     2016-02-01
# 280            NaT
# 282     2021-09-14
# 283            NaT
# 284            NaT
# 285            NaT
# 286            NaT
# 287            NaT
# 288     2021-10-26
# 289     2021-09-16
# 290     2016-02-01
# 291     2021-02-25
# 292     2021-08-13
# 293     2021-08-13
# 294     2021-08-13
# 295     2021-08-13
# 296     2021-09-20
# 297     2021-09-20
# 298     2021-09-20
# 299     2021-09-20
# 300     2021-10-08
# 301     2021-10-08
# 302     2022-02-10
# 303     2022-02-18
# 304     2022-02-18
# 305     2022-02-22
# 306     2022-02-22
# 307     2022-02-22
# 308     2022-03-01
# 309     2022-03-01
# 310     2022-03-29

# %% [markdown]
# # Common Users

# %%
print("Comparision of FHIR to PC")
common_users = fhir_demo.drop_duplicates("user_id").merge(pc_demo.drop_duplicates("user_id"), on="user_id", how="outer", indicator="demo_merge1")
print(common_users['demo_merge1'].value_counts())
common_users = common_users[common_users['demo_merge1'] == 'both']
# Out:
# Comparision of FHIR to PC
# left_only     844
# both          618
# right_only     11
# Name: demo_merge1, dtype: int64

# %% [markdown]
# # Filter FHIR users (run if want to look at subset)

# %%
site_config = {
    'UCSFHEALTHPARTN': 'openepic_shared_ucsf_health',
    'UT1PARTNER': 'openepic_shared_university_of_utah_healthcare',
    'NY1PARTNER': 'openepic_shared_nyu_langone_medical_center',
    'SH2PARTNER': 'openepic_shared_sutter_health',
    'OS2PARTNER': 'openepic_shared_ochsner_health_system',
    'MF1PARTNER': 'openepic_shared_montefiore_medical_center',
    'BA1PARTNER': 'openepic_shared_baylor_scott_white'
}
pc_cond['site'] = pc_cond['siteid']
pc_cond = pc_cond.replace({'site': site_config})

# %%
# get users common to both datasets
common_users_fp = fhir_demo.drop_duplicates("user_id").merge(pc_demo.drop_duplicates("user_id"), on='user_id', how="inner")

print('FHIR conditions all: ', len(fhir_cond), ' users:', len(fhir_cond.drop_duplicates("user_id")))
print('PCORNet conditions all: ', len(pc_cond), ' users:', len(pc_cond.drop_duplicates("user_id")))
fhir_cond_fp = fhir_cond[fhir_cond['user_id'].isin(common_users_fp['user_id'])]
pc_cond_fp = pc_cond[pc_cond['user_id'].isin(common_users_fp['user_id'])]
print("-------- KEEPING ONLY USERS IN BOTH DATASETS -------")
print('FHIR conditions all: ', len(fhir_cond_fp), ' users:', len(fhir_cond_fp.drop_duplicates("user_id")))
print('PCORNet conditions all: ', len(pc_cond_fp), ' users:', len(pc_cond_fp.drop_duplicates("user_id")))
print("-------- KEEPING ONLY SITES IN PCORNET -------")
fhir_cond_fp = fhir_cond_fp[fhir_cond_fp['provider'].isin(site_config.values())]
print('FHIR conditions all: ', len(fhir_cond_fp), ' users:', len(fhir_cond_fp.drop_duplicates("user_id")))
print("-------- KEEPING ONLY ONE SITE PER USER (PCORNET SITE) -------")
common_records = fhir_cond_fp.merge(pc_cond_fp, left_on=['provider', 'user_id'], right_on=['site', 'user_id'], how="inner")
fhir_cond_fp = fhir_cond_fp[fhir_cond_fp['resource_id'].isin(common_records['resource_id'])]
print('FHIR conditions all: ', len(fhir_cond_fp), ' users:', len(fhir_cond_fp.drop_duplicates("user_id")))
# Out:
# FHIR conditions all:  11614  users: 1073
# PCORNet conditions all:  120310  users: 622
# -------- KEEPING ONLY USERS IN BOTH DATASETS -------
# FHIR conditions all:  6343  users: 571
# PCORNet conditions all:  118328  users: 611
# -------- KEEPING ONLY SITES IN PCORNET -------
# FHIR conditions all:  5484  users: 510
# -------- KEEPING ONLY ONE SITE PER USER (PCORNET SITE) -------
# FHIR conditions all:  4987  users: 468

# %% [markdown]
# # Run Comparison Tables

# %%
comparison_config = [
    {
        'title': 'Diabetes', 
        'codes': ['E10','E11'], 
        'ccs_field': 'diabetes', 
        'ccs_yes': [1], 
        'ccs_no': [2]
    },
#     {
#         'title': 'Diabetes General', 
#         'codes': ['E08','E09','E10','E11','E13'], 
#         'ccs_field': 'diabetes', 
#         'ccs_yes': [1], 
#         'ccs_no': [2]
#     },
    {
        'title': 'Hypertension', 
        'codes': ['I10'], 
        'ccs_field': 'hbp', 
        'ccs_yes': [1], 
        'ccs_no': [2]
    },
#     {
#         'title': 'Hypertension General', 
#         'codes': ['I10', 'I11'], 
#         'ccs_field': 'hbp', 
#         'ccs_yes': [1], 
#         'ccs_no': [2]
#     },
    {
        'title': 'Myocardial Infarction',
        'codes': ['I21','I22','I24'],
        'ccs_field': 'heart_attack',
        'ccs_yes': [1], 'ccs_no': [2]
    },
#     {
#         'title': 'Myocardial Infarction General',
#         'codes': ['I20.0', 'I21', 'I22', 'I24', 'I25.2', 'I25.5'],
#         'ccs_field': 'heart_attack',
#         'ccs_yes': [1], 'ccs_no': [2]
#     },
    {
        'title': 'Coronary Artery Disease',
        'codes': ['I20','I21','I22','I23','I24','I25'],
        'ccs_field': 'blockages_in_your_coronary',
        'ccs_yes': [1], 'ccs_no': [2]
    },
    {
        'title': 'Heart Failure',
        'codes': ['I50'],
        'ccs_field': 'chf',
        'ccs_yes': [1], 'ccs_no': [2]
    },
#     {
#         'title': 'Heart Failure General',
#         'codes': ['I11.0','I13.0','I50','I97.13'],
#         'ccs_field': 'chf',
#         'ccs_yes': [1], 'ccs_no': [2]
#     },
    {
        'title': 'Stroke',
        'codes': ['I63'],
        'ccs_field': 'stroke',
        'ccs_yes': [1], 'ccs_no': [2]
    },
    {
        'title': 'AFib',
        'codes': ['I48'],
        'ccs_field': 'afib',
        'ccs_yes': [1], 'ccs_no': [2]
    },
    {
        'title': 'Sleep Apnea',
        'codes': ['G47.3'],
        'ccs_field': 'sleep_apnea',
        'ccs_yes': [1], 'ccs_no': [2]
    },
    {
        'title': 'COPD',
        'codes': ['J44'],
        'ccs_field': 'copd',
        'ccs_yes': [1], 'ccs_no': [2]
    },
    {
        'title': 'Asthma',
        'codes': ['J45'],
        'ccs_field': 'asthma',
        'ccs_yes': [1], 'ccs_no': [2]
    },
    {
        'title': 'Cancer',
        'codes': ['C'],
        'ccs_field': 'cancer',
        'ccs_yes': [1], 'ccs_no': [2]
    },
#     {
#         'title': 'Immunodeficiency',
#         'codes': ['D80', 'D81', 'D82', 'D83', 'D84', 'D70', 'O98.7', 'Z21', 'B20', 'B97.35'],
#         'ccs_field': 'immunodeficiency',
#         'ccs_yes': [1], 'ccs_no': [2]
#     },
#     {
#         'title': 'HIV',
#         'codes': ['Z21', 'B20', 'B97.35', 'O98.7'],
#         'ccs_field': 'HIV',
#         'ccs_yes': [1], 'ccs_no': [2]
#     },
    {
        'title': 'Anemia',
        'codes': ['D50','D51','D52','D53.0','D53.2','D53.9','D64.9'],
        'ccs_field': 'anemia',
        'ccs_yes': [1], 'ccs_no': [2]
    },
#     {
#         'title': 'Anemia General',
#         'codes': ['D46.0','D46.1','D46.4','D46.2','D50','D51','D52','D53.0','D53.2','D53.9','D58.9','D59','D61','D55','D63','D64.9', 'D64.81', 'D64.1', 'D64.2'],
#         'ccs_field': 'anemia',
#         'ccs_yes': [1], 'ccs_no': [2]
#     }
]
# ['diabetes', 'hbp', 'blockages_in_your_coronary', 'heart_attack', 'chf', 'stroke', 'afib', 'sleep_apnea', 'copd', 'asthma', 'cancer', 'immunodeficiency', 'HIV', 'anemia', 'pregnant']

# %%
# SELECT GROUPS YOU WANT TO COMPARE
# site = list(site_config.values())[0]
# print(site)
# fhir_cond_d = fhir_cond[fhir_cond['user_id'].isin(common_users['user_id'])]
fhir_cond_d = fhir_cond[fhir_cond['user_id'].isin(cr_demo['user_id'])]
# fhir_cond_d = fhir_cond_fp[fhir_cond_fp['provider'] == site]
# pc_cond_d = pc_cond[pc_cond['user_id'].isin(common_users['user_id'])]
pc_cond_d = pc_cond[pc_cond['user_id'].isin(cr_demo['user_id'])]
# pc_cond_d = pc_cond_fp[pc_cond_fp['site'] ==  site]
# ccs_cond_d = ccs_cond
common_users_d = fhir_demo.drop_duplicates('user_id').merge(pc_demo.drop_duplicates('user_id'), on='user_id', how="inner").drop_duplicates('user_id')
fhir_cond_d = fhir_cond_d.drop_duplicates(['user_id', 'coding_code'])
pc_cond_d = pc_cond_d.drop_duplicates(['user_id', 'dx'])
# site

# %%
# fv = fhir_cond_d['user_id'].value_counts().reset_index(name='count_fhir')
# fv = fv.rename(columns={'index': 'user_id'})
# pv = pc_cond_d['user_id'].value_counts().reset_index(name='count_pc')
# pv = pv.rename(columns={'index': 'user_id'})
# m = fv.merge(pv, on='user_id', how='outer', indicator="_merge")
# m

# %%
# For Query
# fhir_cond_d[fhir_cond_d['user_id'] == 35829]
# pc_cond_d[pc_cond_d['user_id'] == 458871]

# %%
# For Query
# pc_cond_d[pc_cond_d['user_id'] == 35829]

# %%
def compare(fhir_cond, 
                     pc_cond, 
                     cr_cond,
                     search_icd10_codes, 
                     common_users,
                     ccs_field, 
                     ccs_yes_values=[1], 
                     ccs_no_values=[2], 
                     condition_title=None, 
                     verbose=True):
    fhir_filter = fhir_cond['coding_code'].str.startswith(tuple(search_icd10_codes))
    fhir_cond_s = fhir_cond[fhir_filter].drop_duplicates("user_id")

    
    pc_filter = pc_cond['dx'].str.startswith(tuple(search_icd10_codes))
    pc_cond_s = pc_cond[pc_filter].drop_duplicates("user_id")
    
    cr_filter = cr_cond['diagnostic_code'].str.startswith(tuple(search_icd10_codes))
    cr_cond_s = cr_cond[cr_filter].drop_duplicates("user_id")
    
    fhir = fhir_cond_s.merge(cr_cond_s, on="user_id", how="outer", indicator=True)
    
    pc = pc_cond_s.merge(cr_cond_s, on="user_id", how="outer", indicator=True)
        
    return { 
        'cr': cr_cond_s,
        'pc_agreement': pc[pc['_merge'] == 'both'],
        'pc_missed': pc[pc['_merge'] == 'right_only'],
        'fhir_agreement': fhir[fhir['_merge'] == 'both'],
        'fhir_missed':fhir[fhir['_merge'] == 'right_only']
    }

# fhir_cond_c = fhir_cond[fhir_cond['user_id'].isin(common_users_fp['user_id'])].drop_duplicates(['user_id', 'coding_code'])
# pc_cond_c = pc_cond[pc_cond['user_id'].isin(common_users_fp['user_id'])].drop_duplicates(['user_id', 'dx'])
# ccs_cond_c = ccs_cond[ccs_cond['user_id'].isin(common_users['user_id'])]
print("test run...")
compare(fhir_cond_d, pc_cond_d, cr_cond, ['E10', 'E11'], common_users, 'diabetes', [1], [2])
# Out:
# test run...
# {'cr':      user_id diagnostic_code date_entered           code_source Notes:  \
#  263   457363           E11.9          NaN  Past Medical History    NaN
#
#      date_entered_d
#  263            NaT  ,
#  'pc_agreement': Empty DataFrame
#  Columns: [v1, diagnosisid, encounterid, enc_type, admit_date, dx, dx_type, dx_date, dx_source, pdx, datamartid, siteid, query_date, cdrn_facilityid, dx_date_d, site, user_id, diagnostic_code, date_entered, code_source, Notes:, date_entered_d, _merge]
#  Index: [],
#  'pc_missed':    v1 diagnosisid encounterid enc_type admit_date   dx dx_type dx_date  \
#  0 NaN         NaN         NaN      NaN        NaN  NaN     NaN     NaN
#
#    dx_source  pdx datamartid siteid query_date  cdrn_facilityid dx_date_d site  \
#  0       NaN  NaN        NaN    NaN        NaN              NaN       NaT  NaN
#
#     user_id diagnostic_code date_entered           code_source Notes:  \
#  0   457363           E11.9          NaN  Past Medical History    NaN
#
#    date_entered_d      _merge
#  0            NaT  right_only  ,
#  'fhir_agreement': Empty DataFrame
#  Columns: [resourcetype, provider, uploaded_date, fhir_version, condition_text, coding_system, coding_code, category, resource_id, start, end, recordeddate, verification_text, status, recordeddate_d, start_d, end_d, user_id, diagnostic_code, date_entered, code_source, Notes:, date_entered_d, _merge]
#  Index: [],
#  'fhir_missed':   resourcetype provider uploaded_date fhir_version condition_text  \
#  0          NaN      NaN           NaN          NaN            NaN
#
#    coding_system coding_code category resource_id start  end recordeddate  \
#  0           NaN         NaN      NaN         NaN   NaN  NaN          NaN
#
#    verification_text status recordeddate_d start_d end_d  user_id  \
#  0               NaN    NaN            NaT     NaT   NaT   457363
#
#    diagnostic_code date_entered           code_source Notes: date_entered_d  \
#  0           E11.9          NaN  Past Medical History    NaN            NaT
#
#         _merge
#  0  right_only  }

# %%
result = []
for config in comparison_config:
    print('Processing ', config['title'])
    comp = compare(fhir_cond_d, pc_cond_d, cr_cond, config['codes'], common_users_d, config['ccs_field'], [1], [2])
    resultRow = {
                'Diagnosis Group': config['title'],
                'chart_review': comp['cr']['user_id'].nunique(),
                'pc_agreement': comp['pc_agreement']['user_id'].nunique(),
                'pc_missed': comp['pc_missed']['user_id'].nunique(),
                'fhir_agreement': comp['fhir_agreement']['user_id'].nunique(),
                'fhir_missed': comp['fhir_missed']['user_id'].nunique()
                }
    result.append(resultRow)
result = pd.DataFrame(result)
# Out:
# Processing  Diabetes
# Processing  Hypertension
# Processing  Myocardial Infarction
# Processing  Coronary Artery Disease
# Processing  Heart Failure
# Processing  Stroke
# Processing  AFib
# Processing  Sleep Apnea
# Processing  COPD
# Processing  Asthma
# Processing  Cancer
# Processing  Anemia

# %%
print(f'     Diagnosis of {len(common_users_d)} patients with diagnosis present in:')
grey_columns = [c for c in result.columns if c.startswith('%')]
red_columns = ['Neither']
def highlight_cols(x):
    df = x.copy()
    df.loc[:, :] = 'background-color: none'
    df[grey_columns] = 'color: grey'
#     df[red_columns] = 'color: red'
    return df 
display(result.style.apply(highlight_cols, axis = None))
# Out:
#      Diagnosis of 618 patients with diagnosis present in:
# <style type="text/css">
# #T_45ec9_row0_col0, #T_45ec9_row0_col1, #T_45ec9_row0_col2, #T_45ec9_row0_col3, #T_45ec9_row0_col4, #T_45ec9_row0_col5, #T_45ec9_row1_col0, #T_45ec9_row1_col1, #T_45ec9_row1_col2, #T_45ec9_row1_col3, #T_45ec9_row1_col4, #T_45ec9_row1_col5, #T_45ec9_row2_col0, #T_45ec9_row2_col1, #T_45ec9_row2_col2, #T_45ec9_row2_col3, #T_45ec9_row2_col4, #T_45ec9_row2_col5, #T_45ec9_row3_col0, #T_45ec9_row3_col1, #T_45ec9_row3_col2, #T_45ec9_row3_col3, #T_45ec9_row3_col4, #T_45ec9_row3_col5, #T_45ec9_row4_col0, #T_45ec9_row4_col1, #T_45ec9_row4_col2, #T_45ec9_row4_col3, #T_45ec9_row4_col4, #T_45ec9_row4_col5, #T_45ec9_row5_col0, #T_45ec9_row5_col1, #T_45ec9_row5_col2, #T_45ec9_row5_col3, #T_45ec9_row5_col4, #T_45ec9_row5_col5, #T_45ec9_row6_col0, #T_45ec9_row6_col1, #T_45ec9_row6_col2, #T_45ec9_row6_col3, #T_45ec9_row6_col4, #T_45ec9_row6_col5, #T_45ec9_row7_col0, #T_45ec9_row7_col1, #T_45ec9_row7_col2, #T_45ec9_row7_col3, #T_45ec9_row7_col4, #T_45ec9_row7_col5, #T_45ec9_row8_col0, #T_45ec9_row8_col1, #T_45ec9_row8_col2, #T_45ec9_row8_col3, #T_45ec9_row8_col4, #T_45ec9_row8_col5, #T_45ec9_row9_col0, #T_45ec9_row9_col1, #T_45ec9_row9_col2, #T_45ec9_row9_col3, #T_45ec9_row9_col4, #T_45ec9_row9_col5, #T_45ec9_row10_col0, #T_45ec9_row10_col1, #T_45ec9_row10_col2, #T_45ec9_row10_col3, #T_45ec9_row10_col4, #T_45ec9_row10_col5, #T_45ec9_row11_col0, #T_45ec9_row11_col1, #T_45ec9_row11_col2, #T_45ec9_row11_col3, #T_45ec9_row11_col4, #T_45ec9_row11_col5 {
#   background-color: none;
# }
# </style>
# <table id="T_45ec9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_45ec9_level0_col0" class="col_heading level0 col0" >Diagnosis Group</th>
#       <th id="T_45ec9_level0_col1" class="col_heading level0 col1" >chart_review</th>
#       <th id="T_45ec9_level0_col2" class="col_heading level0 col2" >pc_agreement</th>
#       <th id="T_45ec9_level0_col3" class="col_heading level0 col3" >pc_missed</th>
#       <th id="T_45ec9_level0_col4" class="col_heading level0 col4" >fhir_agreement</th>
#       <th id="T_45ec9_level0_col5" class="col_heading level0 col5" >fhir_missed</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_45ec9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_45ec9_row0_col0" class="data row0 col0" >Diabetes</td>
#       <td id="T_45ec9_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_45ec9_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_45ec9_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_45ec9_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_45ec9_row0_col5" class="data row0 col5" >1</td>
#     </tr>
#     <tr>
#       <th id="T_45ec9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_45ec9_row1_col0" class="data row1 col0" >Hypertension</td>
#       <td id="T_45ec9_row1_col1" class="data row1 col1" >5</td>
#       <td id="T_45ec9_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_45ec9_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_45ec9_row1_col4" class="data row1 col4" >3</td>
#       <td id="T_45ec9_row1_col5" class="data row1 col5" >2</td>
#     </tr>
#     <tr>
#       <th id="T_45ec9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_45ec9_row2_col0" class="data row2 col0" >Myocardial Infarction</td>
#       <td id="T_45ec9_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_45ec9_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_45ec9_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_45ec9_row2_col4" class="data row2 col4" >0</td>
#       <td id="T_45ec9_row2_col5" class="data row2 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_45ec9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_45ec9_row3_col0" class="data row3 col0" >Coronary Artery Disease</td>
#       <td id="T_45ec9_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_45ec9_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_45ec9_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_45ec9_row3_col4" class="data row3 col4" >1</td>
#       <td id="T_45ec9_row3_col5" class="data row3 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_45ec9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_45ec9_row4_col0" class="data row4 col0" >Heart Failure</td>
#       <td id="T_45ec9_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_45ec9_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_45ec9_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_45ec9_row4_col4" class="data row4 col4" >0</td>
#       <td id="T_45ec9_row4_col5" class="data row4 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_45ec9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_45ec9_row5_col0" class="data row5 col0" >Stroke</td>
#       <td id="T_45ec9_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_45ec9_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_45ec9_row5_col3" class="data row5 col3" >0</td>
#       <td id="T_45ec9_row5_col4" class="data row5 col4" >0</td>
#       <td id="T_45ec9_row5_col5" class="data row5 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_45ec9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_45ec9_row6_col0" class="data row6 col0" >AFib</td>
#       <td id="T_45ec9_row6_col1" class="data row6 col1" >1</td>
#       <td id="T_45ec9_row6_col2" class="data row6 col2" >0</td>
#       <td id="T_45ec9_row6_col3" class="data row6 col3" >1</td>
#       <td id="T_45ec9_row6_col4" class="data row6 col4" >0</td>
#       <td id="T_45ec9_row6_col5" class="data row6 col5" >1</td>
#     </tr>
#     <tr>
#       <th id="T_45ec9_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_45ec9_row7_col0" class="data row7 col0" >Sleep Apnea</td>
#       <td id="T_45ec9_row7_col1" class="data row7 col1" >2</td>
#       <td id="T_45ec9_row7_col2" class="data row7 col2" >0</td>
#       <td id="T_45ec9_row7_col3" class="data row7 col3" >2</td>
#       <td id="T_45ec9_row7_col4" class="data row7 col4" >0</td>
#       <td id="T_45ec9_row7_col5" class="data row7 col5" >2</td>
#     </tr>
#     <tr>
#       <th id="T_45ec9_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_45ec9_row8_col0" class="data row8 col0" >COPD</td>
#       <td id="T_45ec9_row8_col1" class="data row8 col1" >0</td>
#       <td id="T_45ec9_row8_col2" class="data row8 col2" >0</td>
#       <td id="T_45ec9_row8_col3" class="data row8 col3" >0</td>
#       <td id="T_45ec9_row8_col4" class="data row8 col4" >0</td>
#       <td id="T_45ec9_row8_col5" class="data row8 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_45ec9_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_45ec9_row9_col0" class="data row9 col0" >Asthma</td>
#       <td id="T_45ec9_row9_col1" class="data row9 col1" >4</td>
#       <td id="T_45ec9_row9_col2" class="data row9 col2" >1</td>
#       <td id="T_45ec9_row9_col3" class="data row9 col3" >3</td>
#       <td id="T_45ec9_row9_col4" class="data row9 col4" >0</td>
#       <td id="T_45ec9_row9_col5" class="data row9 col5" >4</td>
#     </tr>
#     <tr>
#       <th id="T_45ec9_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_45ec9_row10_col0" class="data row10 col0" >Cancer</td>
#       <td id="T_45ec9_row10_col1" class="data row10 col1" >5</td>
#       <td id="T_45ec9_row10_col2" class="data row10 col2" >4</td>
#       <td id="T_45ec9_row10_col3" class="data row10 col3" >1</td>
#       <td id="T_45ec9_row10_col4" class="data row10 col4" >2</td>
#       <td id="T_45ec9_row10_col5" class="data row10 col5" >3</td>
#     </tr>
#     <tr>
#       <th id="T_45ec9_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_45ec9_row11_col0" class="data row11 col0" >Anemia</td>
#       <td id="T_45ec9_row11_col1" class="data row11 col1" >0</td>
#       <td id="T_45ec9_row11_col2" class="data row11 col2" >0</td>
#       <td id="T_45ec9_row11_col3" class="data row11 col3" >0</td>
#       <td id="T_45ec9_row11_col4" class="data row11 col4" >0</td>
#       <td id="T_45ec9_row11_col5" class="data row11 col5

# %%
cr_cond[cr_cond['diagnostic_code'].str.startswith(tuple(['E10','E11']))]
# Out:
#      user_id diagnostic_code date_entered           code_source Notes:  \
# 263   457363           E11.9          NaN  Past Medical History    NaN
#
#     date_entered_d
# 263            NaT

# %%
pc_cond[pc_cond['user_id'] == 457363]
# Out:
#           v1  user_id diagnosisid encounterid enc_type admit_date       dx  \
# 79844  21891   457363    36975389    24406232       TH  20sep2021   M54.12
# 79845  21891   457363    27114891          -1       UN  01jan1900    M51.9
# 79846  21891   457363    80090361    24406232       TH  20sep2021   M54.12
# 79847  21891   457363    30592850    89740581       OA  22feb2022   M48.02
# 79848  21891   457363    70374816    45267177       AV  03may2016    Q79.6
# 79849  21891   457363    81866111    18618086       OA  25feb2021      Z23
# 79850  21891   457363    53433315    89740581       OA  22feb2022   M50.30
# 79851  21891   457363    41784434    89774297       TH  01mar2022   I65.09
# 79852  21891   457363    32012370    89774297       TH  01mar2022   I65.09
# 79853  21891   457363    71303115    89774297       TH  01mar2022   I65.09
# 79854  21891   457363    80670031          -1       UN  01jan1900   M24.80
# 79855  21891   457363    46205153    24406232       TH  20sep2021   M50.30
# 79856  21891   457363    48038482    89740581       OA  22feb2022  Z98.890
# 79857  21891   457363    43373093    24406232       TH  20sep2021    M41.9
# 79858  21891   457363    25269966    89740581       OA  22feb2022   M54.12
# 79859  21891   457363    60733864    24406232       TH  20sep2021   M50.30
# 79860  21891   457363    69618219    45267177       AV  03may2016    Q79.6
# 79861  21891   457363    56538437    24406232       TH  20sep2021   M48.02
# 79862  21891   457363    36980810     1543063       OA  08oct2021   M54.12
# 79863  21891   457363    68482265    24406232       TH  20sep2021    M41.9
# 79864  21891   457363    51730266    89774297       TH  01mar2022  Z98.890
# 79865  21891   457363    66557038     1543063       OA  08oct2021   R06.00
# 79866  21891   457363    73445699    24406232       TH  20sep2021   M48.02
# 79867  21891   457363    77552978    24406232       TH  20sep2021    M41.9
#
#       dx_type    dx_date dx_source pdx datamartid           siteid query_date  \
# 79844      10  20sep2021        OT  OT     C3UCSF  UCSFHEALTHPARTN  17aug2022
# 79845      10  03may2016        OT  OT     C3UCSF  UCSFHEALTHPARTN  17aug2022
# 79846      10  20sep2021        OT  OT     C3UCSF  UCSFHEALTHPARTN  17aug2022
# 79847      10  22feb2022        OT  OT     C3UCSF  UCSFHEALTHPARTN  17aug2022
# 79848      10  03may2016        OT  OT     C3UCSF  UCSFHEALTHPARTN  17aug2022
# 79849      10  25feb2021        OT  OT     C3UCSF  UCSFHEALTHPARTN  17aug2022
# 79850      10  22feb2022        OT  OT     C3UCSF  UCSFHEALTHPARTN  17aug2022
# 79851      10  01mar2022        OT  OT     C3UCSF  UCSFHEALTHPARTN  17aug2022
# 79852      10  01mar2022        OT  OT     C3UCSF  UCSFHEALTHPARTN  17aug2022
# 79853      10  01mar2022        OT  OT     C3UCSF  UCSFHEALTHPARTN  17aug2022
# 79854      10  03may2016        OT  OT     C3UCSF  UCSFHEALTHPARTN  17aug2022
# 79855      10  20sep2021        OT  OT     C3UCSF  UCSFHEALTHPARTN  17aug2022
# 79856      10  22feb2022        OT  OT     C3UCSF  UCSFHEALTHPARTN  17aug2022
# 79857      10  20sep2021        OT  OT     C3UCSF  UCSFHEALTHPARTN  17aug2022
# 79858      10  22feb2022        OT  OT     C3UCSF  UCSFHEALTHPARTN  17aug2022
# 79859      10  20sep2021        OT  OT     C3UCSF  UCSFHEALTHPARTN  17aug2022
# 79860      10  03may2016        AD  OT     C3UCSF  UCSFHEALTHPARTN  17aug2022
# 79861      10  20sep2021        OT  OT     C3UCSF  UCSFHEALTHPARTN  17aug2022
# 79862      10  08oct2021        OT  OT     C3UCSF  UCSFHEALTHPARTN  17aug2022
# 79863      10  20sep2021        OT  OT     C3UCSF  UCSFHEALTHPARTN  17aug2022
# 79864      10  01mar2022        OT  OT     C3UCSF  UCSFHEALTHPARTN  17aug2022
# 79865      10  08oct2021        OT  OT     C3UCSF  UCSFHEALTHPARTN  17aug2022
# 79866      10  20sep2021        OT  OT     C3UCSF  UCSFHEALTHPARTN  17aug2022
# 79867      10  20sep2021        OT  OT     C3UCSF  UCSFHEALTHPARTN  17aug2022
#
#        cdrn_facilityid  dx_date_d                         site
# 79844              NaN 2021-09-20  openepic_shared_ucsf_health
# 79845              NaN 2016-05-03  openepic_shared_ucsf_health
# 79846              NaN 2021-09-20  openepic_shared_ucsf_health
# 79847              NaN 2022-02-22  openepic_shared_ucsf_health
# 79848              NaN 2016-05-03  openepic_shared_ucsf_health
# 79849              NaN 2021-02-25  openepic_shared_ucsf_health
# 79850              NaN 2022-02-22  openepic_shared_ucsf_health
# 79851              NaN 2022-03-01  openepic_shared_ucsf_health
# 79852              NaN 2022-03-01  openepic_shared_ucsf_health
# 79853              NaN 2022-03-01  openepic_shared_ucsf_health
# 79854              NaN 2016-05-03  openepic_shared_ucsf_health
# 79855              NaN 2021-09-20  openepic_shared_ucsf_health
# 79856              NaN 2022-02-22  openepic_shared_ucsf_health
# 79857              NaN 2021-09-20  openepic_shared_ucsf_health
# 79858              NaN 2022-02-22  openepic_shared_ucsf_health
# 79859              NaN 2021-09-20  openepic_shared_ucsf_health
# 79860              NaN 2016-05-03  openepic_shared_ucsf_health
# 79861              NaN 2021-09-20  openepic_shared_ucsf_health
# 79862              NaN 2021-10-08  openepic_shared_ucsf_health
# 79863              NaN 2021-09-20  openepic_shared_ucsf_health
# 79864              NaN 2022-03-01  openepic_shared_ucsf_health
# 79865              NaN 2021-10-08  openepic_shared_ucsf_health
# 79866              NaN 2021-09-20  openepic_shared_ucsf_health
# 79867              NaN 2021-09-20  openepic_shared_ucsf_health

# %%
total_dx = pd.to_numeric(result['Present in Either, N'].str.split(' ', 1, expand=True)[0]).sum()
print('total diagnoses', total_dx)
fhir_dx = pd.to_numeric(result['FHIR'].str.split(' ', 1, expand=True)[0]).sum()
print('Sn of FHIR N', fhir_dx)
print('Sn of FHIR %', fhir_dx / total_dx)
pc_dx = pd.to_numeric(result['PCORnet'].str.split(' ', 1, expand=True)[0]).sum()
print('Sn of PC N', pc_dx)
print('Sn of PC %', pc_dx / total_dx)

pc_total = pd.to_numeric(result['PCORnet'].str.split(' ', 1, expand=True)[0])
pc_p = result['PCORnet'].str.split('(', 1, expand=True)
pc_p[1] = pd.to_numeric(pc_p[1].str[:2])
pc_p[0] = pd.to_numeric(pc_p[0])
pc_p.apply(lambda x: (x[0]*x[1])/100, axis=1).sum()
# pc_p[0].sum()
# Out:
# total diagnoses 35.04
# Sn of FHIR N 14
# Sn of FHIR % 0.3995433789954338
# Sn of PC N 33
# Sn of PC % 0.9417808219178082
# /tmp/ipykernel_12/1088383994.py:1: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   total_dx = pd.to_numeric(result['Present in Either, N'].str.split(' ', 1, expand=True)[0]).sum()
# /tmp/ipykernel_12/1088383994.py:3: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   fhir_dx = pd.to_numeric(result['FHIR'].str.split(' ', 1, expand=True)[0]).sum()
# /tmp/ipykernel_12/1088383994.py:6: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   pc_dx = pd.to_numeric(result['PCORnet'].str.split(' ', 1, expand=True)[0]).sum()
# /tmp/ipykernel_12/1088383994.py:10: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   pc_total = pd.to_numeric(result['PCORnet'].str.split(' ', 1, expand=True)[0])
# /tmp/ipykernel_12/1088383994.py:11: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   pc_p = result['PCORnet'].str.split('(', 1, expand=True)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /usr/local/lib/python3.9/site-packages/pandas/_libs/lib.pyx:2369, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "0%"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 12
#      10 pc_total = pd.to_numeric(result['PCORnet'].str.split(' ', 1, expand=True)[0])
#      11 pc_p = result['PCORnet'].str.split('(', 1, expand=True)
# ---> 12 pc_p[1] = pd.to_numeric(pc_p[1].str[:2])
#      13 pc_p[0] = pd.to_numeric(pc_p[0])
#      14 pc_p.apply(lambda x: (x[0]*x[1])/100, axis=1).sum()
#
# File /usr/local/lib/python3.9/site-packages/pandas/core/tools/numeric.py:185, in to_numeric(arg, errors, downcast)
#     183 coerce_numeric = errors not in ("ignore", "raise")
#     184 try:
# --> 185     values, _ = lib.maybe_convert_numeric(
#     186         values, set(), coerce_numeric=coerce_numeric
#     187     )
#     188 except (ValueError, TypeError):
#     189     if errors == "raise":
#
# File /usr/local/lib/python3.9/site-packages/pandas/_libs/lib.pyx:2411, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "0%" at position 2

# %% [markdown]
# # Query Each direct dx code

# %%
cr_cond_p = cr_cond#[cr_cond['code_source'] == 'Problem List']
# Problem-List Only Conditions
# cr_cond_a = cr_cond_a.drop_duplicates(['user_id', 'diagnostic_code', 'code_source'])
first = cr_cond_p[cr_cond_p['code_source'] == 'Problem List']
second = cr_cond_p[cr_cond_p['code_source'] == 'Past Medical History']
third = cr_cond_p[cr_cond_p['code_source'] == 'Chart Review Tab']
m = first.merge(second, on=['user_id', 'diagnostic_code'], how="outer", indicator='_merge2')
a = m.copy()
m = m[m['_merge2'] == 'left_only']
m = m.merge(third, on=['user_id', 'diagnostic_code'], how="outer", indicator='_merge3')
cr_cond_a = m[m['_merge3'] == 'left_only']
# cr_cond_a = cr_cond_a[cr_cond_a['user_id'] == 35829]

# %%
# cr_cond_a = cr_cond[cr_cond['code_source'] == 'Problem List']

# %%
# PC MERGE
m = pc_cond_d.merge(cr_cond_a, left_on=['user_id', 'dx'], right_on=['user_id', 'diagnostic_code'], how="outer", indicator=True)
missed = m[m['_merge'] == 'right_only']
agreement = m[m['_merge'] == 'both']
c = m['_merge'].value_counts().reset_index(name="counts")
c = c.rename(columns={'index': 'match'})
c['match'] = c['match'].replace({'left_only': 'Extra Codes', 'both': 'Agreement', 'right_only': 'Missed'})
pcornet_results = c
c
# px.bar(m, x='match', y='counts')
# Out:
#          match  counts
# 0  Extra Codes     170
# 1    Agreement      20
# 2       Missed      11

# %%
# FHIR MERGE
m = fhir_cond_d.merge(cr_cond_a, left_on=['user_id', 'coding_code'], right_on=['user_id', 'diagnostic_code'], how="outer", indicator=True)
missed = m[m['_merge'] == 'right_only']
agreement = m[m['_merge'] == 'both']
m = m['_merge'].value_counts().reset_index(name="counts")
m = m.rename(columns={'index': 'match'})
m['match'] = m['match'].replace({'left_only': 'Extra Codes', 'both': 'Agreement', 'right_only': 'Missed'})
fhir_results = m
m
# Out:
#          match  counts
# 0  Extra Codes      62
# 1    Agreement      18
# 2       Missed      13

# %%
pcornet_results['Source'] = 'PCORNet'
fhir_results['Source'] = 'FHIR'
to_plot = pd.concat([pcornet_results, fhir_results])
to_plot = to_plot[~(to_plot['match'] == 'Extra Codes')]
fig = px.bar(to_plot, x='match', y="counts", color="Source", barmode='group', text_auto=True, 
       title="Diagnostic codes by source compared with chart review at UCSF - Problem List Section",
        width=800, height=500)
fig.update_traces(textfont_size=12, textangle=0, textposition="outside", cliponaxis=False)
fig.update_layout(yaxis_range=[0, 50])
fig.update_yaxes(title='Diagnostic Codes (N)')
fig.update_xaxes(title='')
fig.show()
# Out:
# <div>                            <div id="b5f7568f-53b0-4d9f-9fad-58f24d1df64a" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b5f7568f-53b0-4d9f-9fad-58f24d1df64a")) {                    Plotly.newPlot(                        "b5f7568f-53b0-4d9f-9fad-58f24d1df64a",                        [{"alignmentgroup":"True","hovertemplate":"Source=PCORNet<br>match=%{x}<br>counts=%{y}<extra></extra>","legendgroup":"PCORNet","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"PCORNet","offsetgroup":"PCORNet","orientation":"v","showlegend":true,"textposition":"outside","texttemplate":"%{y}","x":["Agreement","Missed"],"xaxis":"x","y":[20,11],"yaxis":"y","type":"bar","textfont":{"size":12},"cliponaxis":false,"textangle":0},{"alignmentgroup":"True","hovertemplate":"Source=FHIR<br>match=%{x}<br>counts=%{y}<extra></extra>","legendgroup":"FHIR","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"FHIR","offsetgroup":"FHIR","orientation":"v","showlegend":true,"textposition":"outside","texttemplate":"%{y}","x":["Agreement","Missed"],"xaxis":"x","y":[18,13],"yaxis":"y","type":"bar","textfont":{"size":12},"cliponaxis":false,"textangle":0}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"pa ...

# %%
missed['user_id'].value_counts()
# Out:
# 457363    16
# 465182     9
# 378622     2
# 458871     1
# 462377     1
# Name: user_id, dtype: int64

# %%
m[m['user_id'] ==457363].sort_values(['user_id','date_entered_d'])
# Out:
#           v1  user_id diagnosisid encounterid enc_type admit_date       dx  \
# 203      NaN   457363         NaN         NaN      NaN        NaN      NaN
# 216      NaN   457363         NaN         NaN      NaN        NaN      NaN
# 205      NaN   457363         NaN         NaN      NaN        NaN      NaN
# 208      NaN   457363         NaN         NaN      NaN        NaN      NaN
# 209      NaN   457363         NaN         NaN      NaN        NaN      NaN
# 124  21891.0   457363    27114891          -1       UN  01jan1900    M51.9
# 130  21891.0   457363    80670031          -1       UN  01jan1900   M24.80
# 215      NaN   457363         NaN         NaN      NaN        NaN      NaN
# 206      NaN   457363         NaN         NaN      NaN        NaN      NaN
# 207      NaN   457363         NaN         NaN      NaN        NaN      NaN
# 212      NaN   457363         NaN         NaN      NaN        NaN      NaN
# 214      NaN   457363         NaN         NaN      NaN        NaN      NaN
# 217      NaN   457363         NaN         NaN      NaN        NaN      NaN
# 213      NaN   457363         NaN         NaN      NaN        NaN      NaN
# 204      NaN   457363         NaN         NaN      NaN        NaN      NaN
# 210      NaN   457363         NaN         NaN      NaN        NaN      NaN
# 211      NaN   457363         NaN         NaN      NaN        NaN      NaN
# 123  21891.0   457363    36975389    24406232       TH  20sep2021   M54.12
# 125  21891.0   457363    30592850    89740581       OA  22feb2022   M48.02
# 126  21891.0   457363    70374816    45267177       AV  03may2016    Q79.6
# 127  21891.0   457363    81866111    18618086       OA  25feb2021      Z23
# 128  21891.0   457363    53433315    89740581       OA  22feb2022   M50.30
# 129  21891.0   457363    41784434    89774297       TH  01mar2022   I65.09
# 131  21891.0   457363    48038482    89740581       OA  22feb2022  Z98.890
# 132  21891.0   457363    43373093    24406232       TH  20sep2021    M41.9
# 133  21891.0   457363    66557038     1543063       OA  08oct2021   R06.00
# 218      NaN   457363         NaN         NaN      NaN        NaN      NaN
#
#     dx_type    dx_date dx_source  pdx datamartid           siteid query_date  \
# 203     NaN        NaN       NaN  NaN        NaN              NaN        NaN
# 216     NaN        NaN       NaN  NaN        NaN              NaN        NaN
# 205     NaN        NaN       NaN  NaN        NaN              NaN        NaN
# 208     NaN        NaN       NaN  NaN        NaN              NaN        NaN
# 209     NaN        NaN       NaN  NaN        NaN              NaN        NaN
# 124      10  03may2016        OT   OT     C3UCSF  UCSFHEALTHPARTN  17aug2022
# 130      10  03may2016        OT   OT     C3UCSF  UCSFHEALTHPARTN  17aug2022
# 215     NaN        NaN       NaN  NaN        NaN              NaN        NaN
# 206     NaN        NaN       NaN  NaN        NaN              NaN        NaN
# 207     NaN        NaN       NaN  NaN        NaN              NaN        NaN
# 212     NaN        NaN       NaN  NaN        NaN              NaN        NaN
# 214     NaN        NaN       NaN  NaN        NaN              NaN        NaN
# 217     NaN        NaN       NaN  NaN        NaN              NaN        NaN
# 213     NaN        NaN       NaN  NaN        NaN              NaN        NaN
# 204     NaN        NaN       NaN  NaN        NaN              NaN        NaN
# 210     NaN        NaN       NaN  NaN        NaN              NaN        NaN
# 211     NaN        NaN       NaN  NaN        NaN              NaN        NaN
# 123      10  20sep2021        OT   OT     C3UCSF  UCSFHEALTHPARTN  17aug2022
# 125      10  22feb2022        OT   OT     C3UCSF  UCSFHEALTHPARTN  17aug2022
# 126      10  03may2016        OT   OT     C3UCSF  UCSFHEALTHPARTN  17aug2022
# 127      10  25feb2021        OT   OT     C3UCSF  UCSFHEALTHPARTN  17aug2022
# 128      10  22feb2022        OT   OT     C3UCSF  UCSFHEALTHPARTN  17aug2022
# 129      10  01mar2022        OT   OT     C3UCSF  UCSFHEALTHPARTN  17aug2022
# 131      10  22feb2022        OT   OT     C3UCSF  UCSFHEALTHPARTN  17aug2022
# 132      10  20sep2021        OT   OT     C3UCSF  UCSFHEALTHPARTN  17aug2022
# 133      10  08oct2021        OT   OT     C3UCSF  UCSFHEALTHPARTN  17aug2022
# 218     NaN        NaN       NaN  NaN        NaN              NaN        NaN
#
#      cdrn_facilityid  dx_date_d                         site diagnostic_code  \
# 203              NaN        NaT                          NaN          G89.29
# 216              NaN        NaT                          NaN           F90.9
# 205              NaN        NaT                          NaN         J45.909
# 208              NaN        NaT                          NaN           E66.9
# 209              NaN        NaT                          NaN           E55.9
# 124              NaN 2016-05-03  openepic_shared_ucsf_health           M51.9
# 130              NaN 2016-05-03  openepic_shared_ucsf_health          M24.80
# 215              NaN        NaT                          NaN          Q79.62
# 206              NaN        NaT                          NaN             I10
# 207              NaN        NaT                          NaN           R23.2
# 212              NaN        NaT                          NaN           N95.0
# 214              NaN        NaT                          NaN         M47.816
# 217              NaN        NaT                          NaN         Z79.891
# 213              NaN        NaT                          NaN         M47.812
# 204              NaN        NaT                          NaN           M79.2
# 210              NaN        NaT                          NaN           N73.6
# 211              NaN        NaT                          NaN           D25.1
# 123              NaN 2021-09-20  openepic_shared_ucsf_health             NaN
# 125              NaN 2022-02-22  openepic_shared_ucsf_health             NaN
# 126              NaN 2016-05-03  openepic_shared_ucsf_health             NaN
# 127              NaN 2021-02-25  openepic_shared_ucsf_health             NaN
# 128              NaN 2022-02-22  openepic_shared_ucsf_health             NaN
# 129              NaN 2022-03-01  openepic_shared_ucsf_health             NaN
# 131              NaN 2022-02-22  openepic_shared_ucsf_health             NaN
# 132              NaN 2021-09-20  openepic_shared_ucsf_health             NaN
# 133              NaN 2021-10-08  openepic_shared_ucsf_health             NaN
# 218              NaN        NaT                          NaN         Z01.818
#
#             date_entered   code_source Notes: date_entered_d      _merge
# 203  2016-01-13 00:00:00  Problem List    NaN     2016-01-13  right_only
# 216  2016-01-13 00:00:00  Problem List    NaN     2016-01-13  right_only
# 205  2016-02-01 00:00:00  Problem List    NaN     2016-02-01  right_only
# 208  2016-02-01 00:00:00  Problem List    NaN     2016-02-01  right_only
# 209  2016-02-01 00:00:00  Problem List    NaN     2016-02-01  right_only
# 124  2016-05-03 00:00:00  Problem List    NaN     2016-05-03        both
# 130  2016-05-03 00:00:00  Problem List    NaN     2016-05-03        both
# 215  2016-05-09 00:00:00  Problem List    NaN     2016-05-09  right_only
# 206  2017-06-05 00:00:00  Problem List    NaN     2017-06-05  right_only
# 207  2018-09-05 00:00:00  Problem List    NaN     2018-09-05  right_only
# 212  2021-09-14 00:00:00  Problem List    NaN     2021-09-14  right_only
# 214  2021-09-16 00:00:00  Problem List    NaN     2021-09-16  right_only
# 217  2021-09-16 00:00:00  Problem List    NaN     2021-09-16  right_only
# 213  2021-10-26 00:00:00  Problem List    NaN     2021-10-26  right_only
# 204  2021-12-07 00:00:00  Problem List    NaN     2021-12-07  right_only
# 210  2022-01-04 00:00:00  Problem List    NaN     2022-01-04  right_only
# 211  2022-01-04 00:00:00  Problem List    NaN     2022-01-04  right_only
# 123                  NaN           NaN    NaN            NaT   left_only
# 125                  NaN           NaN    NaN            NaT   left_only
# 126                  NaN           NaN    NaN            NaT   left_only
# 127                  NaN           NaN    NaN            NaT   left_only
# 128                  NaN           NaN    NaN            NaT   left_only
# 129                  NaN           NaN    NaN            NaT   left_only
# 131                  NaN           NaN    NaN            NaT   left_only
# 132                  NaN           NaN    NaN            NaT   left_only
# 133                  NaN           NaN    NaN            NaT   left_only
# 218                  NaN  Problem List    NaN            NaT  right_only

# %%
pc_cond[pc_cond['user_id'] == 457363]
# Out:
#           v1  user_id diagnosisid encounterid enc_type admit_date       dx  \
# 79844  21891   457363    36975389    24406232       TH  20sep2021   M54.12
# 79845  21891   457363    27114891          -1       UN  01jan1900    M51.9
# 79846  21891   457363    80090361    24406232       TH  20sep2021   M54.12
# 79847  21891   457363    30592850    89740581       OA  22feb2022   M48.02
# 79848  21891   457363    70374816    45267177       AV  03may2016    Q79.6
# 79849  21891   457363    81866111    18618086       OA  25feb2021      Z23
# 79850  21891   457363    53433315    89740581       OA  22feb2022   M50.30
# 79851  21891   457363    41784434    89774297       TH  01mar2022   I65.09
# 79852  21891   457363    32012370    89774297       TH  01mar2022   I65.09
# 79853  21891   457363    71303115    89774297       TH  01mar2022   I65.09
# 79854  21891   457363    80670031          -1       UN  01jan1900   M24.80
# 79855  21891   457363    46205153    24406232       TH  20sep2021   M50.30
# 79856  21891   457363    48038482    89740581       OA  22feb2022  Z98.890
# 79857  21891   457363    43373093    24406232       TH  20sep2021    M41.9
# 79858  21891   457363    25269966    89740581       OA  22feb2022   M54.12
# 79859  21891   457363    60733864    24406232       TH  20sep2021   M50.30
# 79860  21891   457363    69618219    45267177       AV  03may2016    Q79.6
# 79861  21891   457363    56538437    24406232       TH  20sep2021   M48.02
# 79862  21891   457363    36980810     1543063       OA  08oct2021   M54.12
# 79863  21891   457363    68482265    24406232       TH  20sep2021    M41.9
# 79864  21891   457363    51730266    89774297       TH  01mar2022  Z98.890
# 79865  21891   457363    66557038     1543063       OA  08oct2021   R06.00
# 79866  21891   457363    73445699    24406232       TH  20sep2021   M48.02
# 79867  21891   457363    77552978    24406232       TH  20sep2021    M41.9
#
#       dx_type    dx_date dx_source pdx datamartid           siteid query_date  \
# 79844      10  20sep2021        OT  OT     C3UCSF  UCSFHEALTHPARTN  17aug2022
# 79845      10  03may2016        OT  OT     C3UCSF  UCSFHEALTHPARTN  17aug2022
# 79846      10  20sep2021        OT  OT     C3UCSF  UCSFHEALTHPARTN  17aug2022
# 79847      10  22feb2022        OT  OT     C3UCSF  UCSFHEALTHPARTN  17aug2022
# 79848      10  03may2016        OT  OT     C3UCSF  UCSFHEALTHPARTN  17aug2022
# 79849      10  25feb2021        OT  OT     C3UCSF  UCSFHEALTHPARTN  17aug2022
# 79850      10  22feb2022        OT  OT     C3UCSF  UCSFHEALTHPARTN  17aug2022
# 79851      10  01mar2022        OT  OT     C3UCSF  UCSFHEALTHPARTN  17aug2022
# 79852      10  01mar2022        OT  OT     C3UCSF  UCSFHEALTHPARTN  17aug2022
# 79853      10  01mar2022        OT  OT     C3UCSF  UCSFHEALTHPARTN  17aug2022
# 79854      10  03may2016        OT  OT     C3UCSF  UCSFHEALTHPARTN  17aug2022
# 79855      10  20sep2021        OT  OT     C3UCSF  UCSFHEALTHPARTN  17aug2022
# 79856      10  22feb2022        OT  OT     C3UCSF  UCSFHEALTHPARTN  17aug2022
# 79857      10  20sep2021        OT  OT     C3UCSF  UCSFHEALTHPARTN  17aug2022
# 79858      10  22feb2022        OT  OT     C3UCSF  UCSFHEALTHPARTN  17aug2022
# 79859      10  20sep2021        OT  OT     C3UCSF  UCSFHEALTHPARTN  17aug2022
# 79860      10  03may2016        AD  OT     C3UCSF  UCSFHEALTHPARTN  17aug2022
# 79861      10  20sep2021        OT  OT     C3UCSF  UCSFHEALTHPARTN  17aug2022
# 79862      10  08oct2021        OT  OT     C3UCSF  UCSFHEALTHPARTN  17aug2022
# 79863      10  20sep2021        OT  OT     C3UCSF  UCSFHEALTHPARTN  17aug2022
# 79864      10  01mar2022        OT  OT     C3UCSF  UCSFHEALTHPARTN  17aug2022
# 79865      10  08oct2021        OT  OT     C3UCSF  UCSFHEALTHPARTN  17aug2022
# 79866      10  20sep2021        OT  OT     C3UCSF  UCSFHEALTHPARTN  17aug2022
# 79867      10  20sep2021        OT  OT     C3UCSF  UCSFHEALTHPARTN  17aug2022
#
#        cdrn_facilityid  dx_date_d                         site
# 79844              NaN 2021-09-20  openepic_shared_ucsf_health
# 79845              NaN 2016-05-03  openepic_shared_ucsf_health
# 79846              NaN 2021-09-20  openepic_shared_ucsf_health
# 79847              NaN 2022-02-22  openepic_shared_ucsf_health
# 79848              NaN 2016-05-03  openepic_shared_ucsf_health
# 79849              NaN 2021-02-25  openepic_shared_ucsf_health
# 79850              NaN 2022-02-22  openepic_shared_ucsf_health
# 79851              NaN 2022-03-01  openepic_shared_ucsf_health
# 79852              NaN 2022-03-01  openepic_shared_ucsf_health
# 79853              NaN 2022-03-01  openepic_shared_ucsf_health
# 79854              NaN 2016-05-03  openepic_shared_ucsf_health
# 79855              NaN 2021-09-20  openepic_shared_ucsf_health
# 79856              NaN 2022-02-22  openepic_shared_ucsf_health
# 79857              NaN 2021-09-20  openepic_shared_ucsf_health
# 79858              NaN 2022-02-22  openepic_shared_ucsf_health
# 79859              NaN 2021-09-20  openepic_shared_ucsf_health
# 79860              NaN 2016-05-03  openepic_shared_ucsf_health
# 79861              NaN 2021-09-20  openepic_shared_ucsf_health
# 79862              NaN 2021-10-08  openepic_shared_ucsf_health
# 79863              NaN 2021-09-20  openepic_shared_ucsf_health
# 79864              NaN 2022-03-01  openepic_shared_ucsf_health
# 79865              NaN 2021-10-08  openepic_shared_ucsf_health
# 79866              NaN 2021-09-20  openepic_shared_ucsf_health
# 79867              NaN 2021-09-20  openepic_shared_ucsf_health
