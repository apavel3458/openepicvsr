# %%
import pandas as pd
import numpy as np
import plotly.express as px
from lib.DrugUtil import flatten, DrugUtil

import plotly.express as px
from lib.FhirDataUtil import FhirDataUtil
from lib.CCSDataUtil import CCSDataUtil

def printmd(string):
    display(string)

# %load_ext autoreload
# %autoreload 2

pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_colwidth', None)

_fhir_conditions_file = "input/fhir_conditions_20221003.csv"
_fhir_medications_file = "input/fhir_medications_20221003.csv"
_fhir_medications_ref_file = "input/fhir_medications_references_20221003.csv"
_fhir_demographics_file = "input/fhir_demographics_20221113.csv"
_output_dir = 'output/'

_rxnorm_file = "input_static/RxTerms202203/RxTerms202203.txt"
_rxnorm_ingredients_file = "input_static/RxTerms202203/RxTermsIngredients202203.txt"
_rxclass_file = "input_static/_rxclass_2022-04-10.csv"

_ccs_demographics_file = "input/ccs_demographics.csv"
_ccs_medications_file = "input/ccs_medications.csv"
_ccs_conditions_file = "input/ccs_conditions.csv"

_pc_demographics_file = "input/pcornet/demographic_fhir.csv"
_pc_medications_file = "input/pcornet/med_adm_fhir.csv"

# %%
drugUtil = DrugUtil()
drugUtil.load(rxnorm_file=_rxnorm_file,
                        rxnorm_ingredients_file=_rxnorm_ingredients_file, 
                        rxclass_file=_rxclass_file)

fhirUtil = FhirDataUtil()
ccsUtil = CCSDataUtil(drugUtil)

fhirUtil.load_conditions(fhir_conditions_file=_fhir_conditions_file, remove_health_concerns=True)
fhirUtil.load_demographics(fhir_demographics_file=_fhir_demographics_file)

ccsUtil.load_conditions(ccs_conditions_file= _ccs_conditions_file)
ccsUtil.load_demographics(_ccs_demographics_file)
# Out:
# Reading rxclass file...
# Reading rxnorm file...
# Loaded FHIR conditions records: 37248
# /app/lib/CCSDataUtil.py:13: DtypeWarning: Columns (5,6,11,12,13,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.conditions = pd.read_csv(ccs_conditions_file, delimiter=',')
# Loaded CCS conditions records: 94735
# Loaded demographics file with entries:  98877
# /app/lib/CCSDataUtil.py:75: DtypeWarning: Columns (11,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.demographics = pd.read_csv(ccs_demographics)

# %%
snomed = fhirUtil.conditions[fhirUtil.conditions['coding_system'] == 'SNOMED']
print(f'Number of snomeds: {len(snomed)}')
icd10 = fhirUtil.conditions[fhirUtil.conditions['coding_system'] == 'ICD10']
print(f'Number of ICD10s: {len(icd10)}')
# Out:
# Number of snomeds: 19850
# Number of ICD10s: 17398

# %%
pc_cond = pd.read_csv('input/pcornet/diagnosis_fhir.csv')
pc_demo = pd.read_csv('input/pcornet/demographic_fhir.csv')
# Out:
# /tmp/ipykernel_37/4266438744.py:1: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   pc_cond = pd.read_csv('input/pcornet/diagnosis_fhir.csv')

# %%
fhir_cond = icd10
fhir_demo = fhirUtil.demographics
ccs_cond = ccsUtil.conditions
ccs_demo = ccsUtil.demographics

# %% [markdown]
# # Common Users

# %%
print("Comparision of FHIR to PC")
common_users = fhir_demo.drop_duplicates("user_id").merge(pc_demo.drop_duplicates("user_id"), on="user_id", how="outer", indicator="demo_merge1")
print(common_users['demo_merge1'].value_counts())
common_users = common_users[common_users['demo_merge1'] == 'both']

print("Comparison of CCS To others")
common_users = common_users.merge(ccs_demo.drop_duplicates("user_id"), on="user_id", how="outer", indicator="demo_merge2")
print(common_users['demo_merge2'].value_counts())

common_users = common_users[common_users['demo_merge2'] == 'both'].drop_duplicates("user_id")
print('Total common users: ', len(common_users))
# Out:
# Comparision of FHIR to PC
# left_only     844
# both          618
# right_only     11
# Name: demo_merge1, dtype: int64
# Comparison of CCS To others
# right_only    98260
# both            616
# left_only         2
# Name: demo_merge2, dtype: int64
# Total common users:  616

# %% [markdown]
# # Filter FHIR users (run if want to look at subset)

# %%
site_config = {
    'UCSFHEALTHPARTN': 'openepic_shared_ucsf_health',
    'UT1PARTNER': 'openepic_shared_university_of_utah_healthcare',
    'NY1PARTNER': 'openepic_shared_nyu_langone_medical_center',
    'SH2PARTNER': 'openepic_shared_sutter_health',
    'OS2PARTNER': 'openepic_shared_ochsner_health_system',
    'MF1PARTNER': 'openepic_shared_montefiore_medical_center',
    'BA1PARTNER': 'openepic_shared_baylor_scott_white'
}
pc_cond['site'] = pc_cond['siteid']
pc_cond = pc_cond.replace({'site': site_config})
# Out:
# FHIR conditions all:  17398

# %%
# get users common to both datasets
common_users_fp = fhir_demo.drop_duplicates("user_id").merge(pc_demo.drop_duplicates("user_id"), on='user_id', how="inner")

print('FHIR conditions all: ', len(fhir_cond), ' users:', len(fhir_cond.drop_duplicates("user_id")))
print('PCORNet conditions all: ', len(pc_cond), ' users:', len(pc_cond.drop_duplicates("user_id")))
fhir_cond_fp = fhir_cond[fhir_cond['user_id'].isin(common_users_fp['user_id'])]
pc_cond_fp = pc_cond[pc_cond['user_id'].isin(common_users_fp['user_id'])]
print("-------- KEEPING ONLY USERS IN BOTH DATASETS -------")
print('FHIR conditions all: ', len(fhir_cond_fp), ' users:', len(fhir_cond_fp.drop_duplicates("user_id")))
print('PCORNet conditions all: ', len(pc_cond_fp), ' users:', len(pc_cond_fp.drop_duplicates("user_id")))
print("-------- KEEPING ONLY SITES IN PCORNET -------")
fhir_cond_fp = fhir_cond_fp[fhir_cond_fp['provider'].isin(site_config.values())]
print('FHIR conditions all: ', len(fhir_cond_fp), ' users:', len(fhir_cond_fp.drop_duplicates("user_id")))
print("-------- KEEPING ONLY ONE SITE PER USER (PCORNET SITE) -------")
common_records = fhir_cond_fp.merge(pc_cond_fp, on=['provider', 'user_id'], how="inner")
common_records
# Out:
# FHIR conditions all:  17398  users: 1144
# PCORNet conditions all:  120358  users: 622
# -------- KEEPING ONLY USERS IN BOTH DATASETS -------
# FHIR conditions all:  9535  users: 600
# PCORNet conditions all:  118373  users: 611
# -------- KEEPING ONLY SITES IN PCORNET -------
# FHIR conditions all:  8348  users: 531
# -------- KEEPING ONLY ONE SITE PER USER (PCORNET SITE) -------
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[88], line 15
#      13 print('FHIR conditions all: ', len(fhir_cond_fp), ' users:', len(fhir_cond_fp.drop_duplicates("user_id")))
#      14 print("-------- KEEPING ONLY ONE SITE PER USER (PCORNET SITE) -------")
# ---> 15 common_records = fhir_cond_fp.merge(pc_cond_fp, on=['provider', 'user_id'], how="inner")
#      16 common_records
#
# File /usr/local/lib/python3.9/site-packages/pandas/core/frame.py:10090, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10071 @Substitution("")
#   10072 @Appender(_merge_doc, indents=2)
#   10073 def merge(
#    (...)
#   10086     validate: str | None = None,
#   10087 ) -> DataFrame:
#   10088     from pandas.core.reshape.merge import merge
# > 10090     return merge(
#   10091         self,
#   10092         right,
#   10093         how=how,
#   10094         on=on,
#   10095         left_on=left_on,
#   10096         right_on=right_on,
#   10097         left_index=left_index,
#   10098         right_index=right_index,
#   10099         sort=sort,
#   10100         suffixes=suffixes,
#   10101         copy=copy,
#   10102         indicator=indicator,
#   10103         validate=validate,
#   10104     )
#
# File /usr/local/lib/python3.9/site-packages/pandas/core/reshape/merge.py:110, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      93 @Substitution("\nleft : DataFrame or named Series")
#      94 @Appender(_merge_doc, indents=0)
#      95 def merge(
#    (...)
#     108     validate: str | None = None,
#     109 ) -> DataFrame:
# --> 110     op = _MergeOperation(
#     111         left,
#     112         right,
#     113         how=how,
#     114         on=on,
#     115         left_on=left_on,
#     116         right_on=right_on,
#     117         left_index=left_index,
#     118         right_index=right_index,
#     119         sort=sort,
#     120         suffixes=suffixes,
#     121         indicator=indicator,
#     122         validate=validate,
#     123     )
#     124     return op.get_result(copy=copy)
#
# File /usr/local/lib/python3.9/site-packages/pandas/core/reshape/merge.py:703, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, indicator, validate)
#     696 self._cross = cross_col
#     698 # note this function has side effects
#     699 (
#     700     self.left_join_keys,
#     701     self.right_join_keys,
#     702     self.join_names,
# --> 703 ) = self._get_merge_keys()
#     705 # validate the merge keys dtypes. We may need to coerce
#     706 # to avoid incompatible dtypes
#     707 self._maybe_coerce_merge_keys()
#
# File /usr/local/lib/python3.9/site-packages/pandas/core/reshape/merge.py:1162, in _MergeOperation._get_merge_keys(self)
#    1160 rk = cast(Hashable, rk)
#    1161 if rk is not None:
# -> 1162     right_keys.append(right._get_label_or_level_values(rk))
#    1163 else:
#    1164     # work-around for merge_asof(right_index=True)
#    1165     right_keys.append(right.index)
#
# File /usr/local/lib/python3.9/site-packages/pandas/core/generic.py:1850, in NDFrame._get_label_or_level_values(self, key, axis)
#    1844     values = (
#    1845         self.axes[axis]
#    1846         .get_level_values(key)  # type: ignore[assignment]
#    1847         ._values
#    1848     )
#    1849 else:
# -> 1850     raise KeyError(key)
#    1852 # Check for duplicates
#    1853 if values.ndim > 1:
#
# KeyError: 'provider'

# %%
fhir_cond['provider'].value_counts()
# Out:
# openepic_shared_sutter_health                                              4008
# openepic_shared_ucsf_health                                                1999
# openepic_shared_university_of_utah_healthcare                              1929
# openepic_shared_nyu_langone_medical_center                                 1231
# openepic_shared_ochsner_health_system                                      1078
# openepic_shared_baylor_scott_white                                          474
# openepic_shared_montefiore_medical_center                                   461
# openepic_shared_john_muir_health                                            303
# openepic_shared_stanford_health_care                                        286
# openepic_shared_brown_toland_physicians                                     284
# openepic_shared_kaiser_permanente_california_northern                       211
# openepic_shared_texas_health_resources                                      171
# openepic_shared_penn_medicine                                               170
# openepic_shared_mount_sinai_health_system                                   131
# openepic_shared_edward_elmhurst_healthcare                                  126
# openepic_shared_ssm_health                                                  112
# openepic_shared_ochin                                                       112
# openepic_shared_fairview_health_services                                    108
# openepic_shared_vanderbilt                                                  100
# openepic_shared_houston_methodist                                            90
# openepic_shared_healthpartners                                               83
# openepic_shared_uw_medicine_washington                                       83
# openepic_shared_the_ohio_state_university_wexner_medical_center              81
# openepic_shared_kaiser_permanente_california_southern                        81
# openepic_shared_contra_costa                                                 80
# openepic_shared_allina_health_system                                         79
# openepic_shared_michigan_medicine                                            78
# openepic_shared_unitypoint_health                                            76
# openepic_shared_university_of_arkansas_for_medical_sciences                  75
# openepic_shared_lehigh_valley_health_network                                 74
# openepic_shared_university_of_california_san_diego                           71
# openepic_shared_ucsf_benioff_children_s_hospital                             71
# openepic_shared_bronson_healthcare_group                                     69
# openepic_shared_duly_health_and_care                                         69
# openepic_shared_san_francisco_department_of_public_health                    67
# openepic_shared_uc_davis                                                     66
# openepic_shared_scripps_health                                               62
# openepic_shared_atrium_health                                                61
# openepic_shared_johns_hopkins_medicine                                       61
# openepic_shared_rush_university_medical_center                               60
# openepic_shared_ucla_medical_center                                          57
# openepic_shared_prisma_health                                                56
# openepic_shared_novant_health                                                55
# openepic_shared_asante_health_systems                                        52
# openepic_shared_inova_and_valley_health                                      50
# openepic_shared_peacehealth                                                  49
# openepic_shared_lcmc_health                                                  48
# openepic_shared_weill_cornell_medicine                                       48
# openepic_shared_austin_regional_clinic                                       47
# openepic_shared_riverside_health_system_newport_news_va                      46
# openepic_shared_hospital_for_special_surgery                                 46
# openepic_shared_eisenhower_medical_center                                    44
# openepic_shared_unc_health_care                                              44
# openepic_shared_wakemed_health_and_hospitals                                 43
# openepic_shared_uc_health                                                    43
# openepic_shared_sansum_clinic                                                42
# openepic_shared_community_medical_centers                                    42
# openepic_shared_geisinger                                                    41
# openepic_shared_nyc_health_hospitals                                         41
# openepic_shared_spectrum_health                                              41
# openepic_shared_templehealth                                                 40
# openepic_shared_hartford_healthcare                                          39
# openepic_shared_beaumont_health                                              38
# openepic_shared_arizona_community_physicians                                 37
# openepic_shared_loma_linda_university_health_and_careconnect_partners        37
# openepic_shared_honorhealth                                                  37
# openepic_shared_mercy_medical_center                                         33
# openepic_shared_allegheny_health_network                                     33
# openepic_shared_columbia_physicians                                          33
# openepic_shared_umass_memorial_health_care                                   32
# openepic_shared_oregon_health_science_university                             32
# openepic_shared_rwjbarnabas_health                                           31
# openepic_shared_northshore_university_health_system                          31
# openepic_shared_the_guthrie_clinic                                           30
# openepic_shared_ann_robert_h_lurie_children_s_hospital_of_chicago            30
# openepic_shared_sentara_healthcare                                           30
# openepic_shared_university_of_vermont_medical_center                         28
# openepic_shared_west_virginia_university_medicine                            28
# openepic_shared_mainehealth                                                  27
# openepic_shared_quadmed                                                      27
# openepic_shared_adventist_health_west                                        26
# openepic_shared_firsthealth_of_the_carolinas                                 26
# openepic_shared_wellspan_health                                              25
# openepic_shared_hackensack_meridian_health                                   25
# openepic_shared_boulder_community_health                                     24
# openepic_shared_catholic_health_long_island_ny                               23
# openepic_shared_nebraska_medicine                                            23
# openepic_shared_hospital_sisters_health_system_hshs                          23
# openepic_shared_duke_health                                                  22
# openepic_shared_trinity_health                                               22
# openepic_shared_orlando_health                                               22
# openepic_shared_kaiser_permanente_oregon_sw_washington                       22
# openepic_shared_ui_health                                                    22
# openepic_shared_loyola_medicine                                              22
# openepic_shared_franciscan_missionaries_of_our_lady_health_system            22
# openepic_shared_lancaster_general_health                                     22
# openepic_shared_buffalo_medical_group                                        22
# openepic_shared_university_of_louisville_physicians                          21
# openepic_shared_trinity_health_of_new_england                                20
# openepic_shared_baptist_health_arkansas                                      20
# openepic_shared_bon_secours_health_system                                    20
# openepic_shared_yale_new_haven_health_system                                 20
# openepic_shared_mount_auburn_hospital                                        19
# openepic_shared_north_memorial_health                                        19
# openepic_shared_samaritan_health_services                                    19
# openepic_shared_parkland                                                     17
# openepic_shared_bjc_washington_university                                    17
# openepic_shared_montage_health                                               16
# openepic_shared_alameda_health_system                                        16
# openepic_shared_scl_health                                                   15
# openepic_shared_hill_physicians                                              15
# openepic_shared_shannon_health                                               15
# openepic_shared_united_health_services_new_york_nyuhs                        14
# openepic_shared_presbyterian_healthcare_services                             14
# openepic_shared_solutionhealth                                               13
# openepic_shared_piedmont_healthcare                                          13
# openepic_shared_washington_hospital_healthcare_system                        12
# openepic_shared_university_of_kansas_health_system                           12
# openepic_shared_main_line_health                                             12
# openepic_shared_university_of_rochester_medical_center_prd                   12
# openepic_shared_city_of_hope                                                 12
# openepic_shared_riverside_medical_center                                     11
# openepic_shared_ohiohealth                                                   11
# openepic_shared_st_luke_s_health_system_idaho_eastern_oregon                 10
# openepic_shared_cigna_medical_group                                          10
# openepic_shared_university_of_pittsburgh_medical_center_upmc                 10
# openepic_shared_the_queen_s_health_systems                                   10
# openepic_shared_institute_for_family_health                                   9
# openepic_shared_metrohealth_oh                                                8
# openepic_shared_norton_healthcare                                             7
# openepic_shared_franciscan_alliance                                           7
# openepic_shared_uc_davis_mmc                                                  7
# openepic_shared_promedica_health_system                                       7
# openepic_shared_lee_health                                                    6
# openepic_shared_kaiser_permanente_colorado                                    6
# openepic_shared_kaiser_permanente_maryland_virginia_washington_d_c            6
# openepic_shared_kettering_health_network                                      6
# openepic_shared_henry_ford_health_system                                      6
# openepic_shared_trihealth                                                     5
# openepic_shared_the_portland_clinic                                           5
# openepic_shared_sanford_health                                                5
# openepic_shared_palos_health                                                  5
# openepic_shared_grady_health_system                                           4
# openepic_shared_university_of_maryland_medical_system                         4
# openepic_shared_group_health_cooperative_south_central_wisconsin              4
# openepic_shared_overlake_hospital_medical_center                              3
# openepic_shared_arkansas_children_s                                           3
# openepic_shared_ardent                                                        3
# openepic_shared_lahey_health_system                                           3
# openepic_shared_integris_health                                               3
# openepic_shared_wellstar                                                      3
# openepic_shared_renown_barton_cvmc                                            2
# openepic_shared_st_joseph_hospital_health_center                              2
# openepic_shared_luminis_health                                                2
# openepic_shared_uchicago_medicine                                             2
# openepic_shared_santa_clara_valley_medical_center_hospitals_and_clinics       2
# openepic_shared_midmichigan_health                                            2
# openepic_shared_atlantic_health                                               1
# openepic_shared_the_everett_clinic                                            1
# openepic_shared_community_healthcare_system                                   1
# test1                                                                         1
# Name: provider, dtype: int64

# %% [markdown]
# # Run Comparison Tables

# %%
comparison_config = [
    {
        'title': 'Diabetes', 
        'codes': ['E10','E11'], 
        'ccs_field': 'diabetes', 
        'ccs_yes': [1], 
        'ccs_no': [2]
    },
#     {
#         'title': 'Diabetes General', 
#         'codes': ['E08','E09','E10','E11','E13'], 
#         'ccs_field': 'diabetes', 
#         'ccs_yes': [1], 
#         'ccs_no': [2]
#     },
    {
        'title': 'Hypertension', 
        'codes': ['I10'], 
        'ccs_field': 'hbp', 
        'ccs_yes': [1], 
        'ccs_no': [2]
    },
#     {
#         'title': 'Hypertension General', 
#         'codes': ['I10', 'I11'], 
#         'ccs_field': 'hbp', 
#         'ccs_yes': [1], 
#         'ccs_no': [2]
#     },
    {
        'title': 'Myocardial Infarction',
        'codes': ['I21','I22','I24'],
        'ccs_field': 'heart_attack',
        'ccs_yes': [1], 'ccs_no': [2]
    },
#     {
#         'title': 'Myocardial Infarction General',
#         'codes': ['I20.0', 'I21', 'I22', 'I24', 'I25.2', 'I25.5'],
#         'ccs_field': 'heart_attack',
#         'ccs_yes': [1], 'ccs_no': [2]
#     },
    {
        'title': 'Coronary Artery Disease',
        'codes': ['I20','I21','I22','I23','I24','I25'],
        'ccs_field': 'blockages_in_your_coronary',
        'ccs_yes': [1], 'ccs_no': [2]
    },
    {
        'title': 'Heart Failure',
        'codes': ['I50'],
        'ccs_field': 'chf',
        'ccs_yes': [1], 'ccs_no': [2]
    },
#     {
#         'title': 'Heart Failure General',
#         'codes': ['I11.0','I13.0','I50','I97.13'],
#         'ccs_field': 'chf',
#         'ccs_yes': [1], 'ccs_no': [2]
#     },
    {
        'title': 'Stroke',
        'codes': ['I63'],
        'ccs_field': 'stroke',
        'ccs_yes': [1], 'ccs_no': [2]
    },
    {
        'title': 'AFib',
        'codes': ['I48'],
        'ccs_field': 'afib',
        'ccs_yes': [1], 'ccs_no': [2]
    },
    {
        'title': 'Sleep Apnea',
        'codes': ['G47.3'],
        'ccs_field': 'sleep_apnea',
        'ccs_yes': [1], 'ccs_no': [2]
    },
    {
        'title': 'COPD',
        'codes': ['J44'],
        'ccs_field': 'copd',
        'ccs_yes': [1], 'ccs_no': [2]
    },
    {
        'title': 'Asthma',
        'codes': ['J45'],
        'ccs_field': 'asthma',
        'ccs_yes': [1], 'ccs_no': [2]
    },
    {
        'title': 'Cancer',
        'codes': ['C'],
        'ccs_field': 'cancer',
        'ccs_yes': [1], 'ccs_no': [2]
    },
    {
        'title': 'Immunodeficiency',
        'codes': ['D80', 'D81', 'D82', 'D83', 'D84', 'D70', 'O98.7', 'Z21', 'B20', 'B97.35'],
        'ccs_field': 'immunodeficiency',
        'ccs_yes': [1], 'ccs_no': [2]
    },
    {
        'title': 'HIV',
        'codes': ['Z21', 'B20', 'B97.35', 'O98.7'],
        'ccs_field': 'HIV',
        'ccs_yes': [1], 'ccs_no': [2]
    },
    {
        'title': 'Anemia',
        'codes': ['D50','D51','D52','D53.0','D53.2','D53.9','D64.9'],
        'ccs_field': 'anemia',
        'ccs_yes': [1], 'ccs_no': [2]
    },
#     {
#         'title': 'Anemia General',
#         'codes': ['D46.0','D46.1','D46.4','D46.2','D50','D51','D52','D53.0','D53.2','D53.9','D58.9','D59','D61','D55','D63','D64.9', 'D64.81', 'D64.1', 'D64.2'],
#         'ccs_field': 'anemia',
#         'ccs_yes': [1], 'ccs_no': [2]
#     }
]
# ['diabetes', 'hbp', 'blockages_in_your_coronary', 'heart_attack', 'chf', 'stroke', 'afib', 'sleep_apnea', 'copd', 'asthma', 'cancer', 'immunodeficiency', 'HIV', 'anemia', 'pregnant']

# %%
def compare(ccs_cond, 
                     fhir_cond, 
                     pc_cond, 
                     search_icd10_codes, 
                     common_users,
                     ccs_field, 
                     ccs_yes_values=[1], 
                     ccs_no_values=[2], 
                     condition_title=None, 
                     verbose=True):
    fhir_filter = fhir_cond['coding_code'].str.startswith(tuple(search_icd10_codes))
    fhir_cond_s = fhir_cond[fhir_filter].drop_duplicates("user_id")
    
    pc_filter = pc_cond['dx'].str.startswith(tuple(search_icd10_codes))
    pc_cond_s = pc_cond[pc_filter].drop_duplicates("user_id")
    
    ccs_filter = ccs_cond[ccs_field].isin(ccs_yes_values)
    ccs_cond_s = ccs_cond[ccs_filter].drop_duplicates('user_id')
    
    fp_all = fhir_cond_s.merge(pc_cond_s, on="user_id", how="inner")
    
    fp_any = pd.concat([fhir_cond_s['user_id'], pc_cond_s['user_id']]).drop_duplicates()
    
    
    fp_none = common_users[~common_users['user_id'].isin(fp_any)]
    
    return { 'fp_all': len(fp_all),
            'fp_any': len(fp_any),
            'fhir': len(fhir_cond_s),
            'pc': len(pc_cond_s),
            'fp_none': len(fp_none),
    }

fhir_cond_c = fhir_cond[fhir_cond['user_id'].isin(common_users_fp['user_id'])].drop_duplicates(['user_id', 'coding_code'])
pc_cond_c = pc_cond[pc_cond['user_id'].isin(common_users_fp['user_id'])].drop_duplicates(['user_id', 'dx'])
ccs_cond_c = ccs_cond[ccs_cond['user_id'].isin(common_users['user_id'])]
print("test run...")
compare(ccs_cond_c, fhir_cond_c, pc_cond_c, ['E10', 'E11'], common_users, 'diabetes', [1], [2])
# Out:
# test run...
# {'fp_all': 46, 'fp_any': 82, 'fhir': 57, 'pc': 71, 'fp_none': 535}

# %%
result = []
for config in comparison_config:
    print('Processing ', config['title'])
    comp = compare(ccs_cond_c, fhir_cond_c, pc_cond_c, config['codes'], common_users, config['ccs_field'], [1], [2])

    resultRow = {
                'Diagnosis Group': config['title'],
                'FHIR Only': str(comp['fhir']) + ' (' + str(round((comp['fhir']*100)/len(common_users))) + '%)',
                'PC Only': str(comp['pc']) + ' (' + str(round((comp['pc']*100)/len(common_users))) + '%)',
                'Both': str(comp['fp_all']) + ' (' + str(round((comp['fp_all']*100)/len(common_users))) + '%)',
                'Either': str(comp['fp_any']) + ' (' + str(round((comp['fp_any']*100)/len(common_users))) + '%)',
                'Neither': comp['fp_none'],
                }
    result.append(resultRow)
result = pd.DataFrame(result)
# Out:
# Processing  Diabetes
# Processing  Hypertension
# Processing  Myocardial Infarction
# Processing  Coronary Artery Disease
# Processing  Heart Failure
# Processing  Stroke
# Processing  AFib
# Processing  Sleep Apnea
# Processing  COPD
# Processing  Asthma
# Processing  Cancer
# Processing  Immunodeficiency
# Processing  HIV
# Processing  Anemia

# %%
print(f'     Diagnosis of {len(common_users)} patients with diagnosis present in:')
grey_columns = [c for c in result.columns if c.startswith('%')]
red_columns = ['Neither']
def highlight_cols(x):
    df = x.copy()
    df.loc[:, :] = 'background-color: none'
    df[grey_columns] = 'color: grey'
    df[red_columns] = 'color: red'
    return df 
display(result.style.apply(highlight_cols, axis = None))
# Out:
#      Diagnosis of 616 patients with diagnosis present in:
# <style type="text/css">
# #T_f021c_row0_col0, #T_f021c_row0_col1, #T_f021c_row0_col2, #T_f021c_row0_col3, #T_f021c_row0_col4, #T_f021c_row1_col0, #T_f021c_row1_col1, #T_f021c_row1_col2, #T_f021c_row1_col3, #T_f021c_row1_col4, #T_f021c_row2_col0, #T_f021c_row2_col1, #T_f021c_row2_col2, #T_f021c_row2_col3, #T_f021c_row2_col4, #T_f021c_row3_col0, #T_f021c_row3_col1, #T_f021c_row3_col2, #T_f021c_row3_col3, #T_f021c_row3_col4, #T_f021c_row4_col0, #T_f021c_row4_col1, #T_f021c_row4_col2, #T_f021c_row4_col3, #T_f021c_row4_col4, #T_f021c_row5_col0, #T_f021c_row5_col1, #T_f021c_row5_col2, #T_f021c_row5_col3, #T_f021c_row5_col4, #T_f021c_row6_col0, #T_f021c_row6_col1, #T_f021c_row6_col2, #T_f021c_row6_col3, #T_f021c_row6_col4, #T_f021c_row7_col0, #T_f021c_row7_col1, #T_f021c_row7_col2, #T_f021c_row7_col3, #T_f021c_row7_col4, #T_f021c_row8_col0, #T_f021c_row8_col1, #T_f021c_row8_col2, #T_f021c_row8_col3, #T_f021c_row8_col4, #T_f021c_row9_col0, #T_f021c_row9_col1, #T_f021c_row9_col2, #T_f021c_row9_col3, #T_f021c_row9_col4, #T_f021c_row10_col0, #T_f021c_row10_col1, #T_f021c_row10_col2, #T_f021c_row10_col3, #T_f021c_row10_col4, #T_f021c_row11_col0, #T_f021c_row11_col1, #T_f021c_row11_col2, #T_f021c_row11_col3, #T_f021c_row11_col4, #T_f021c_row12_col0, #T_f021c_row12_col1, #T_f021c_row12_col2, #T_f021c_row12_col3, #T_f021c_row12_col4, #T_f021c_row13_col0, #T_f021c_row13_col1, #T_f021c_row13_col2, #T_f021c_row13_col3, #T_f021c_row13_col4 {
#   background-color: none;
# }
# #T_f021c_row0_col5, #T_f021c_row1_col5, #T_f021c_row2_col5, #T_f021c_row3_col5, #T_f021c_row4_col5, #T_f021c_row5_col5, #T_f021c_row6_col5, #T_f021c_row7_col5, #T_f021c_row8_col5, #T_f021c_row9_col5, #T_f021c_row10_col5, #T_f021c_row11_col5, #T_f021c_row12_col5, #T_f021c_row13_col5 {
#   color: red;
# }
# </style>
# <table id="T_f021c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f021c_level0_col0" class="col_heading level0 col0" >Diagnosis Group</th>
#       <th id="T_f021c_level0_col1" class="col_heading level0 col1" >FHIR Only</th>
#       <th id="T_f021c_level0_col2" class="col_heading level0 col2" >PC Only</th>
#       <th id="T_f021c_level0_col3" class="col_heading level0 col3" >Both</th>
#       <th id="T_f021c_level0_col4" class="col_heading level0 col4" >Either</th>
#       <th id="T_f021c_level0_col5" class="col_heading level0 col5" >Neither</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f021c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f021c_row0_col0" class="data row0 col0" >Diabetes</td>
#       <td id="T_f021c_row0_col1" class="data row0 col1" >57 (9%)</td>
#       <td id="T_f021c_row0_col2" class="data row0 col2" >71 (12%)</td>
#       <td id="T_f021c_row0_col3" class="data row0 col3" >46 (7%)</td>
#       <td id="T_f021c_row0_col4" class="data row0 col4" >82 (13%)</td>
#       <td id="T_f021c_row0_col5" class="data row0 col5" >535</td>
#     </tr>
#     <tr>
#       <th id="T_f021c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f021c_row1_col0" class="data row1 col0" >Hypertension</td>
#       <td id="T_f021c_row1_col1" class="data row1 col1" >194 (31%)</td>
#       <td id="T_f021c_row1_col2" class="data row1 col2" >213 (35%)</td>
#       <td id="T_f021c_row1_col3" class="data row1 col3" >161 (26%)</td>
#       <td id="T_f021c_row1_col4" class="data row1 col4" >246 (40%)</td>
#       <td id="T_f021c_row1_col5" class="data row1 col5" >371</td>
#     </tr>
#     <tr>
#       <th id="T_f021c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f021c_row2_col0" class="data row2 col0" >Myocardial Infarction</td>
#       <td id="T_f021c_row2_col1" class="data row2 col1" >8 (1%)</td>
#       <td id="T_f021c_row2_col2" class="data row2 col2" >8 (1%)</td>
#       <td id="T_f021c_row2_col3" class="data row2 col3" >3 (0%)</td>
#       <td id="T_f021c_row2_col4" class="data row2 col4" >13 (2%)</td>
#       <td id="T_f021c_row2_col5" class="data row2 col5" >603</td>
#     </tr>
#     <tr>
#       <th id="T_f021c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f021c_row3_col0" class="data row3 col0" >Coronary Artery Disease</td>
#       <td id="T_f021c_row3_col1" class="data row3 col1" >37 (6%)</td>
#       <td id="T_f021c_row3_col2" class="data row3 col2" >60 (10%)</td>
#       <td id="T_f021c_row3_col3" class="data row3 col3" >31 (5%)</td>
#       <td id="T_f021c_row3_col4" class="data row3 col4" >66 (11%)</td>
#       <td id="T_f021c_row3_col5" class="data row3 col5" >551</td>
#     </tr>
#     <tr>
#       <th id="T_f021c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f021c_row4_col0" class="data row4 col0" >Heart Failure</td>
#       <td id="T_f021c_row4_col1" class="data row4 col1" >10 (2%)</td>
#       <td id="T_f021c_row4_col2" class="data row4 col2" >22 (4%)</td>
#       <td id="T_f021c_row4_col3" class="data row4 col3" >9 (1%)</td>
#       <td id="T_f021c_row4_col4" class="data row4 col4" >23 (4%)</td>
#       <td id="T_f021c_row4_col5" class="data row4 col5" >594</td>
#     </tr>
#     <tr>
#       <th id="T_f021c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f021c_row5_col0" class="data row5 col0" >Stroke</td>
#       <td id="T_f021c_row5_col1" class="data row5 col1" >4 (1%)</td>
#       <td id="T_f021c_row5_col2" class="data row5 col2" >5 (1%)</td>
#       <td id="T_f021c_row5_col3" class="data row5 col3" >2 (0%)</td>
#       <td id="T_f021c_row5_col4" class="data row5 col4" >7 (1%)</td>
#       <td id="T_f021c_row5_col5" class="data row5 col5" >609</td>
#     </tr>
#     <tr>
#       <th id="T_f021c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f021c_row6_col0" class="data row6 col0" >AFib</td>
#       <td id="T_f021c_row6_col1" class="data row6 col1" >30 (5%)</td>
#       <td id="T_f021c_row6_col2" class="data row6 col2" >29 (5%)</td>
#       <td id="T_f021c_row6_col3" class="data row6 col3" >21 (3%)</td>
#       <td id="T_f021c_row6_col4" class="data row6 col4" >38 (6%)</td>
#       <td id="T_f021c_row6_col5" class="data row6 col5" >579</td>
#     </tr>
#     <tr>
#       <th id="T_f021c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f021c_row7_col0" class="data row7 col0" >Sleep Apnea</td>
#       <td id="T_f021c_row7_col1" class="data row7 col1" >89 (14%)</td>
#       <td id="T_f021c_row7_col2" class="data row7 col2" >99 (16%)</td>
#       <td id="T_f021c_row7_col3" class="data row7 col3" >67 (11%)</td>
#       <td id="T_f021c_row7_col4" class="data row7 col4" >121 (20%)</td>
#       <td id="T_f021c_row7_col5" class="data row7 col5" >496</td>
#     </tr>
#     <tr>
#       <th id="T_f021c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f021c_row8_col0" class="data row8 col0" >COPD</td>
#       <td id="T_f021c_row8_col1" class="data row8 col1" >17 (3%)</td>
#       <td id="T_f021c_row8_col2" class="data row8 col2" >22 (4%)</td>
#       <td id="T_f021c_row8_col3" class="data row8 col3" >12 (2%)</td>
#       <td id="T_f021c_row8_col4" class="data row8 col4" >27 (4%)</td>
#       <td id="T_f021c_row8_col5" class="data row8 col5" >590</td>
#     </tr>
#     <tr>
#       <th id="T_f021c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f021c_row9_col0" class="data row9 col0" >Asthma</td>
#       <td id="T_f021c_row9_col1" class="data row9 col1" >79 (13%)</td>
#       <td id="T_f021c_row9_col2" class="data row9 col2" >98 (16%)</td>
#       <td id="T_f021c_row9_col3" class="data row9 col3" >62 (10%)</td>
#       <td id="T_f021c_row9_col4" class="data row9 col4" >115 (19%)</td>
#       <td id="T_f021c_row9_col5" class="data row9 col5" >502</td>
#     </tr>
#     <tr>
#       <th id="T_f021c_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_f021c_row10_col0" class="data row10 col0" >Cancer</td>
#       <td id="T_f021c_row10_col1" class="data row10 col1" >94 (15%)</td>
#       <td id="T_f021c_row10_col2" class="data row10 col2" >112 (18%)</td>
#       <td id="T_f021c_row10_col3" class="data row10 col3" >81 (13%)</td>
#       <td id="T_f021c_row10_col4" class="data row10 col4" >125 (20%)</td>

# %% [markdown]
# # PcorNet

# %%
pc_cond = pd.read_csv('input/pcornet/diagnosis_fhir.csv')
pc_demo = pd.read_csv('input/pcornet/demographic_fhir.csv')
# Out:
# /var/folders/_n/j7wb5zn173d8t_tnxz9rb5p00000gn/T/ipykernel_10275/4266438744.py:1: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   pc_cond = pd.read_csv('input/pcornet/diagnosis_fhir.csv')

# %%
fhir_demo = fhirUtil.demographics.drop_duplicates(subset="user_id")
fhir_cond = fhirUtil.conditions[fhirUtil.conditions['coding_system'] == 'ICD10']

# %%
ccs_cond = ccsUtil.conditions

# %%
m_demo = pc_demo.drop_duplicates(subset="user_id").merge(fhir_demo.drop_duplicates(subset="user_id"), on="user_id", indicator=True, how="outer")
common_users = m_demo[m_demo['_merge'] == 'both']
m_demo['_merge'].value_counts()
# Out:
# right_only    844
# both          618
# left_only      11
# Name: _merge, dtype: int64

# %%
print('Common total fhir users:', len(fhir_demo[fhir_demo['user_id'].isin(common_users['user_id'])].drop_duplicates('user_id')))
print('Common total pcornet users:', len(pc_demo[pc_demo['user_id'].isin(common_users['user_id'])].drop_duplicates('user_id')))
fhir_cond_pc = fhir_cond[fhir_cond['user_id'].isin(common_users['user_id'])]
pc_cond_fhir = pc_cond[pc_cond['user_id'].isin(common_users['user_id'])]
print('Common fhir users with conditions: ', len(fhir_cond_pc.drop_duplicates('user_id')))
print('Common Pcornet users with conditions:', len(pc_cond_fhir.drop_duplicates('user_id')))
# Out:
# Common total fhir users: 618
# Common total pcornet users: 618
# Common fhir users with conditions:  600
# Common Pcornet users with conditions: 611

# %%
def compare(left, right, codes, left_field, right_field, verbose=True):
#         {
#         'title': 'Diabetes', 
#         'codes': ['E10','E11'], 
#         'ccs_field': 'diabetes', 
#         'ccs_yes': [1], 
#         'ccs_no': [2]
#     },
    
    left_filter = left[left_field].str.startswith(tuple(codes))
    left_s = left[left_filter].drop_duplicates(subset='user_id')
    left_no_s = common_users[~common_users["user_id"].isin(left_s['user_id'])].drop_duplicates(subset='user_id')
    
    right_filter = right[right_field].str.startswith(tuple(codes))
    right_s = right[right_filter].drop_duplicates(subset="user_id")
    right_no_s = common_users[~common_users["user_id"].isin(right_s['user_id'])].drop_duplicates(subset='user_id')
    
    m = left_s.merge(right_s, on="user_id", how="outer", indicator=True)
    
    left_no_s.drop('_merge', axis=1, inplace=True)
    right_no_s.drop('_merge', axis=1, inplace=True)
    m_no = left_no_s.merge(right_no_s, on="user_id", how="outer", indicator=True)
    
    both_positive = m[m['_merge']=='both']
    left_only = m[m['_merge'] == 'left_only']
    right_only = m[m['_merge'] == 'right_only']
    
    both_negative = m_no[m_no['_merge'] == 'both']
    
    r = {
        'both_len': len(both_positive),
        'left_only_len': len(left_only),
        'right_only_len': len(right_only),
        'both_negative_len': len(both_negative),
        'total_yes': len(both_positive)+len(left_only)+len(right_only),
        'total_no': len(left_only)+len(right_only)+len(both_negative)
    }
    return r
    
    
result = []
for config in comparison_config:
    print('Processing ', config['title'])
    comp = compare(
                               left=fhir_cond_pc,
                               right=pc_cond_fhir,
                               codes=config['codes'], 
                               left_field= 'coding_code',
                               right_field='dx',
                               verbose=False)

    resultRow = {
    'title': config['title'],
    'Both Pos': comp['both_len'],
    'CF %': round((comp['both_len']*100)/comp['total_yes']),
    'FHIR Pos': comp['left_only_len'],
    'C %': round((comp['left_only_len']*100)/comp['total_yes']),
    'PCORNET Pos': comp['right_only_len'],
    'F %': round((comp['right_only_len']*100)/comp['total_yes']),
    'Both Negative': comp['both_negative_len'],
    'BN %': round((comp['both_negative_len']*100)/(comp['total_no']))
    }
    result.append(resultRow)
result_df = pd.DataFrame(result)

grey_columns = ['CF %', 'F %', 'C %', 'BN %']
red_columns = ['FHIR Pos', 'PCORNET Pos']
green_columns = ['Both Pos', 'Both Negative']
def highlight_cols(x):
    df = x.copy()
    df.loc[:, :] = 'background-color: none'
    df[grey_columns] = 'color: grey'
    df[red_columns] = 'color: red'
    df[green_columns] = 'color: green'
    return df 
display(result_df.style.apply(highlight_cols, axis = None))

# result_df
# Out:
# Processing  Diabetes
# Processing  Diabetes General
# Processing  Hypertension
# Processing  Hypertension General
# Processing  Myocardial Infarction
# Processing  Myocardial Infarction General
# Processing  Coronary Artery Disease
# Processing  Heart Failure
# Processing  Heart Failure General
# Processing  Stroke
# Processing  AFib
# Processing  Sleep Apnea
# Processing  COPD
# Processing  Asthma
# Processing  Cancer
# Processing  Immunodeficiency
# Processing  HIV
# Processing  Anemia
# Processing  Anemia General
# <style type="text/css">
# #T_39008_row0_col0, #T_39008_row1_col0, #T_39008_row2_col0, #T_39008_row3_col0, #T_39008_row4_col0, #T_39008_row5_col0, #T_39008_row6_col0, #T_39008_row7_col0, #T_39008_row8_col0, #T_39008_row9_col0, #T_39008_row10_col0, #T_39008_row11_col0, #T_39008_row12_col0, #T_39008_row13_col0, #T_39008_row14_col0, #T_39008_row15_col0, #T_39008_row16_col0, #T_39008_row17_col0, #T_39008_row18_col0 {
#   background-color: none;
# }
# #T_39008_row0_col1, #T_39008_row0_col7, #T_39008_row1_col1, #T_39008_row1_col7, #T_39008_row2_col1, #T_39008_row2_col7, #T_39008_row3_col1, #T_39008_row3_col7, #T_39008_row4_col1, #T_39008_row4_col7, #T_39008_row5_col1, #T_39008_row5_col7, #T_39008_row6_col1, #T_39008_row6_col7, #T_39008_row7_col1, #T_39008_row7_col7, #T_39008_row8_col1, #T_39008_row8_col7, #T_39008_row9_col1, #T_39008_row9_col7, #T_39008_row10_col1, #T_39008_row10_col7, #T_39008_row11_col1, #T_39008_row11_col7, #T_39008_row12_col1, #T_39008_row12_col7, #T_39008_row13_col1, #T_39008_row13_col7, #T_39008_row14_col1, #T_39008_row14_col7, #T_39008_row15_col1, #T_39008_row15_col7, #T_39008_row16_col1, #T_39008_row16_col7, #T_39008_row17_col1, #T_39008_row17_col7, #T_39008_row18_col1, #T_39008_row18_col7 {
#   color: green;
# }
# #T_39008_row0_col2, #T_39008_row0_col4, #T_39008_row0_col6, #T_39008_row0_col8, #T_39008_row1_col2, #T_39008_row1_col4, #T_39008_row1_col6, #T_39008_row1_col8, #T_39008_row2_col2, #T_39008_row2_col4, #T_39008_row2_col6, #T_39008_row2_col8, #T_39008_row3_col2, #T_39008_row3_col4, #T_39008_row3_col6, #T_39008_row3_col8, #T_39008_row4_col2, #T_39008_row4_col4, #T_39008_row4_col6, #T_39008_row4_col8, #T_39008_row5_col2, #T_39008_row5_col4, #T_39008_row5_col6, #T_39008_row5_col8, #T_39008_row6_col2, #T_39008_row6_col4, #T_39008_row6_col6, #T_39008_row6_col8, #T_39008_row7_col2, #T_39008_row7_col4, #T_39008_row7_col6, #T_39008_row7_col8, #T_39008_row8_col2, #T_39008_row8_col4, #T_39008_row8_col6, #T_39008_row8_col8, #T_39008_row9_col2, #T_39008_row9_col4, #T_39008_row9_col6, #T_39008_row9_col8, #T_39008_row10_col2, #T_39008_row10_col4, #T_39008_row10_col6, #T_39008_row10_col8, #T_39008_row11_col2, #T_39008_row11_col4, #T_39008_row11_col6, #T_39008_row11_col8, #T_39008_row12_col2, #T_39008_row12_col4, #T_39008_row12_col6, #T_39008_row12_col8, #T_39008_row13_col2, #T_39008_row13_col4, #T_39008_row13_col6, #T_39008_row13_col8, #T_39008_row14_col2, #T_39008_row14_col4, #T_39008_row14_col6, #T_39008_row14_col8, #T_39008_row15_col2, #T_39008_row15_col4, #T_39008_row15_col6, #T_39008_row15_col8, #T_39008_row16_col2, #T_39008_row16_col4, #T_39008_row16_col6, #T_39008_row16_col8, #T_39008_row17_col2, #T_39008_row17_col4, #T_39008_row17_col6, #T_39008_row17_col8, #T_39008_row18_col2, #T_39008_row18_col4, #T_39008_row18_col6, #T_39008_row18_col8 {
#   color: grey;
# }
# #T_39008_row0_col3, #T_39008_row0_col5, #T_39008_row1_col3, #T_39008_row1_col5, #T_39008_row2_col3, #T_39008_row2_col5, #T_39008_row3_col3, #T_39008_row3_col5, #T_39008_row4_col3, #T_39008_row4_col5, #T_39008_row5_col3, #T_39008_row5_col5, #T_39008_row6_col3, #T_39008_row6_col5, #T_39008_row7_col3, #T_39008_row7_col5, #T_39008_row8_col3, #T_39008_row8_col5, #T_39008_row9_col3, #T_39008_row9_col5, #T_39008_row10_col3, #T_39008_row10_col5, #T_39008_row11_col3, #T_39008_row11_col5, #T_39008_row12_col3, #T_39008_row12_col5, #T_39008_row13_col3, #T_39008_row13_col5, #T_39008_row14_col3, #T_39008_row14_col5, #T_39008_row15_col3, #T_39008_row15_col5, #T_39008_row16_col3, #T_39008_row16_col5, #T_39008_row17_col3, #T_39008_row17_col5, #T_39008_row18_col3, #T_39008_row18_col5 {
#   color: red;
# }
# </style>
# <table id="T_39008">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_39008_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_39008_level0_col1" class="col_heading level0 col1" >Both Pos</th>
#       <th id="T_39008_level0_col2" class="col_heading level0 col2" >CF %</th>
#       <th id="T_39008_level0_col3" class="col_heading level0 col3" >FHIR Pos</th>
#       <th id="T_39008_level0_col4" class="col_heading level0 col4" >C %</th>
#       <th id="T_39008_level0_col5" class="col_heading level0 col5" >PCORNET Pos</th>
#       <th id="T_39008_level0_col6" class="col_heading level0 col6" >F %</th>
#       <th id="T_39008_level0_col7" class="col_heading level0 col7" >Both Negative</th>
#       <th id="T_39008_level0_col8" class="col_heading level0 col8" >BN %</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_39008_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_39008_row0_col0" class="data row0 col0" >Diabetes</td>
#       <td id="T_39008_row0_col1" class="data row0 col1" >46</td>
#       <td id="T_39008_row0_col2" class="data row0 col2" >56</td>
#       <td id="T_39008_row0_col3" class="data row0 col3" >11</td>
#       <td id="T_39008_row0_col4" class="data row0 col4" >13</td>
#       <td id="T_39008_row0_col5" class="data row0 col5" >25</td>
#       <td id="T_39008_row0_col6" class="data row0 col6" >30</td>
#       <td id="T_39008_row0_col7" class="data row0 col7" >536</td>
#       <td id="T_39008_row0_col8" class="data row0 col8" >94</td>
#     </tr>
#     <tr>
#       <th id="T_39008_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_39008_row1_col0" class="data row1 col0" >Diabetes General</td>
#       <td id="T_39008_row1_col1" class="data row1 col1" >47</td>
#       <td id="T_39008_row1_col2" class="data row1 col2" >57</td>
#       <td id="T_39008_row1_col3" class="data row1 col3" >10</td>
#       <td id="T_39008_row1_col4" class="data row1 col4" >12</td>
#       <td id="T_39008_row1_col5" class="data row1 col5" >25</td>
#       <td id="T_39008_row1_col6" class="data row1 col6" >30</td>
#       <td id="T_39008_row1_col7" class="data row1 col7" >536</td>
#       <td id="T_39008_row1_col8" class="data row1 col8" >94</td>
#     </tr>
#     <tr>
#       <th id="T_39008_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_39008_row2_col0" class="data row2 col0" >Hypertension</td>
#       <td id="T_39008_row2_col1" class="data row2 col1" >161</td>
#       <td id="T_39008_row2_col2" class="data row2 col2" >65</td>
#       <td id="T_39008_row2_col3" class="data row2 col3" >33</td>
#       <td id="T_39008_row2_col4" class="data row2 col4" >13</td>
#       <td id="T_39008_row2_col5" class="data row2 col5" >52</td>
#       <td id="T_39008_row2_col6" class="data row2 col6" >21</td>
#       <td id="T_39008_row2_col7" class="data row2 col7" >372</td>
#       <td id="T_39008_row2_col8" class="data row2 col8" >81</td>
#     </tr>
#     <tr>
#       <th id="T_39008_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_39008_row3_col0" class="data row3 col0" >Hypertension General</td>
#       <td id="T_39008_row3_col1" class="data row3 col1" >161</td>
#       <td id="T_39008_row3_col2" class="data row3 col2" >65</td>
#       <td id="T_39008_row3_col3" class="data row3 col3" >33</td>
#       <td id="T_39008_row3_col4" class="data row3 col4" >13</td>
#       <td id="T_39008_row3_col5" class="data row3 col5" >54</td>
#       <td id="T_39008_row3_col6" class="data row3 col6" >22</td>
#       <td id="T_39008_row3_col7" class="data row3 col7" >370</td>
#       <td id="T_39008_row3_col8" class="data row3 col8" >81</td>
#     </tr>
#     <tr>
#       <th id="T_39008_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_39008_row4_col0" class="data row4 col0" >Myocardial Infarction</td>
#       <td id="T_39008_row4_col1" class="data row4 col1" >3</td>
#       <td id="T_39008_row4_col2" class="data row4 col2" >23</td>
#       <td id="T_39008_row4_col3" class="data row4 col3" >5</td>
#       <td id="T_39008_row4_col4" class="data row4 col4" >38</td>
#       <td id="T_39008_row4_col5" class="data row4 col5" >5</td>
#       <td id="T_39008_row4_col6" class="data row4 col6" >38</td>
#       <td id="T_39008_row4_col7" class="data row4 col7" >605</td>
#       <td id="T_39008_row4_col8" class="data row4 col8" >98</td>
#     </tr>
#     <tr>
#       <th id="T_39008_level0_row5" class="row_heading level0 row5" >

# %%
# Check dataset
fhir_cond_pc
pc_cond_fhir
# Out:
#            v1  user_id                             diagnosisid   encounterid  \
# 0          26   502639  {C21B53E3-3272-44D4-B1F8-78F25CC597AC}    1038398261
# 1          26   502639  {59185F2E-E7D9-46E3-A311-FAC5D67022FE}    1136833765
# 2          26   502639  {C9E93863-78D8-4CDC-90F5-D7C65E02D443}     892747432
# 3          26   502639  {A5730640-15ED-411F-BD29-6181EB5C662D}     936074887
# 4          26   502639  {7F719426-21A7-463B-84F0-1A29012FF1C3}    1072911350
# ...       ...      ...                                     ...           ...
# 120339  48641   547213                               842348168  UTAH10581382
# 120340  48641   547213                               548738098  UTAH11794463
# 120341  48641   547213                                25928655  UTAH10581382
# 120342  48641   547213                               873757065  UTAH21035279
# 120343  48641   547213                               623111735  UTAH21420430
#
#        enc_type admit_date      dx dx_type    dx_date dx_source pdx  \
# 0            OA  14jun2020   J31.0      10  14jun2020        FI   S
# 1            OA  23nov2021  M79.18      10  23nov2021        FI   S
# 2            AV  19jan2018     Z23      10  19jan2018        FI   S
# 3            AV  14sep2018   R92.2      10  14sep2018        FI   S
# 4            OA  30dec2020   I49.9      10  30dec2020        FI   S
# ...         ...        ...     ...     ...        ...       ...  ..
# 120339       AV  10aug2017  Z00.00      10        NaN        FI   P
# 120340       AV  18dec2017  J01.00      10        NaN        FI   P
# 120341       AV  10aug2017   Z12.4      10        NaN        FI   S
# 120342       AV  03mar2021     Z23      10        NaN        FI   P
# 120343       AV  07apr2021     Z23      10        NaN        FI   P
#
#        datamartid      siteid query_date  cdrn_facilityid
# 0          SUTTER  SH2PARTNER  14jun2022              NaN
# 1          SUTTER  SH2PARTNER  14jun2022              NaN
# 2          SUTTER  SH2PARTNER  14jun2022              NaN
# 3          SUTTER  SH2PARTNER  14jun2022              NaN
# 4          SUTTER  SH2PARTNER  14jun2022              NaN
# ...           ...         ...        ...              ...
# 120339       C4UU  UT1PARTNER  13jun2022              NaN
# 120340       C4UU  UT1PARTNER  13jun2022              NaN
# 120341       C4UU  UT1PARTNER  13jun2022              NaN
# 120342       C4UU  UT1PARTNER  13jun2022              NaN
# 120343       C4UU  UT1PARTNER  13jun2022              NaN
#
# [118373 rows x 15 columns]

# %%
pc_users = pc_cond_fhir[pc_cond_fhir['dx'].str.startswith(('E10', 'E11'))].drop_duplicates(subset="user_id")
fhir_users = fhir_cond_pc[fhir_cond_pc['coding_code'].str.startswith(('E10', 'E11'))].drop_duplicates(subset="user_id")

# %%
len(fhir_users[~fhir_users['user_id'].isin(pc_users['user_id'])])
# Out:
# 11

# %%
len(common_users[~common_users['user_id'].isin((*pc_users, *fhir_users))])
# Out:
# 536

# %%
len([1647, 16853, 102891, 117086, 200552, 302382, 324260, 324726, 324961, 331019, 331110, 331135, 331300, 331450, 331467, 331515, 331920, 333749, 344968, 357029, 383858, 386617, 387173, 387417, 388923, 389802, 395485, 395659, 395756, 397160, 399087]
)
# Out:
# 31
