# %%
import pandas as pd
import numpy as np
import plotly.express as px
from mylib import flatten, EurekaUtil
from IPython.display import display, HTML
import time

# %load_ext autoreload
# %autoreload 2

_rxnorm_ingredients_txt_path = "/Users/bubbles/src/python/OpenEpic/libraries/RxTerms202203/RxTermsIngredients202203.txt"
_class_output_csv_path = "/Users/bubbles/src/python/OpenEpic/output/rxclass.csv"
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
eureka_util = EurekaUtil(_rxnorm_ingredients_txt_path)

# %%
## Query RxClass API
rxcui = 5487
search_str = 'codein'
result = eureka_util.searchIngredientByName(search_str)
print(result)
if len(result) == 0:
    print('rxcui not found')
else:
    rxcui = result['ING_RXCUI'][0]
    print(f'Using {rxcui}')
    classTypes_ignore = ['DISEASE', 'PE', 'MOA', 'CHEM', 'STRUCT', 'DISPOS', 'EPC', 'PK']
    removeClassTypes = True
    classType = ['ATC1-4']
    onlyClassTypes = False
    url_s = f'https://rxnav.nlm.nih.gov/REST/rxclass/class/byRxcui.json?rxcui={str(rxcui)}'
    # with urllib.request.urlopen(url_s) as url:
    #     json = json.loads(url.read().decode())
    json = pd.read_json(url_s)
    for item in json['rxclassDrugInfoList']['rxclassDrugInfo']:
        if (item['minConcept']['rxcui'] == str(rxcui)
            and (
                (removeClassTypes and item['rxclassMinConceptItem']['classType'] not in classTypes_ignore)
            or  (onlyClassTypes and item['rxclassMinConceptItem']['classType'] in classType)
                )
            ):
            #         print(item['minConcept'])
            print(item['rxclassMinConceptItem'])
# Out:
#    ING_RXCUI      INGREDIENT
# 0       2670         codeine
# 1      23088  dihydrocodeine
# Using 2670
# {'classId': 'D000701', 'className': 'Analgesics, Opioid', 'classType': 'MESHPA'}
# {'classId': 'D000996', 'className': 'Antitussive Agents', 'classType': 'MESHPA'}
# {'classId': 'D009294', 'className': 'Narcotics', 'classType': 'MESHPA'}
# {'classId': 'R05DA', 'className': 'Opium alkaloids and derivatives', 'classType': 'ATC1-4'}

# %%
rxcui1 = 2670
rxcui2 = 10582
classType = 'ATC1-4'
trans = 0 # DIRECT relations only
print("Reading classes from RxClass API")
url_s = f'https://rxnav.nlm.nih.gov/REST/rxclass/allClasses.json?classTypes={classType}&trans={trans}'
# with urllib.request.urlopen(url_s) as url:
#     json = json.loads(url.read().decode())
json = pd.read_json(url_s)

classes = json['rxclassMinConceptList']['rxclassMinConcept']
classes = pd.DataFrame(classes)
print(f'Successfully read {len(classes)} classes from RxClass API!')
classes.head()
# Out:
# Reading classes from RxClass API
# Successfully read 1297 classes from RxClass API!
#   classId                                 className classType
# 0       0  Anatomical Therapeutic Chemical (ATC1-4)    ATC1-4
# 1       A           ALIMENTARY TRACT AND METABOLISM    ATC1-4
# 2     A01               STOMATOLOGICAL PREPARATIONS    ATC1-4
# 3    A01A               STOMATOLOGICAL PREPARATIONS    ATC1-4
# 4   A01AA                Caries prophylactic agents    ATC1-4

# %%
eureka_util.loadAllClasses(['ATC1-4'])
eureka_util.rxclasses.head()
# Out:
# Reading classes from RxClass API
# Successfully read 1297 classes from RxClass API!
#   classId                                 className classType
# 0       0  Anatomical Therapeutic Chemical (ATC1-4)    ATC1-4
# 1       A           ALIMENTARY TRACT AND METABOLISM    ATC1-4
# 2     A01               STOMATOLOGICAL PREPARATIONS    ATC1-4
# 3    A01A               STOMATOLOGICAL PREPARATIONS    ATC1-4
# 4   A01AA                Caries prophylactic agents    ATC1-4

# %%
agg = []
final_df = pd.DataFrame()

# %%
_batch = 100
_step = 0 # starts with 0
_wait = 0.5 # seconds

# aggregator = pd.DataFrame([], 
#                           columns=['classId', 'className', 'classType'])
_start = _batch*_step
_stop = _batch*(_step+1)

_start = 1290
_stop = 1299
subset = eureka_util.rxclasses.iloc[_start:_stop,:]
subset
# Out:
#      classId                                          className classType
# 1290   V10AX  Other antiinflammatory therapeutic radiopharma...    ATC1-4
# 1291    V10B              PAIN PALLIATION (BONE SEEKING AGENTS)    ATC1-4
# 1292   V10BX       Various pain palliation radiopharmaceuticals    ATC1-4
# 1293    V10X             OTHER THERAPEUTIC RADIOPHARMACEUTICALS    ATC1-4
# 1294   V10XA                            Iodine (131I) compounds    ATC1-4
# 1295   V10XX           Various therapeutic radiopharmaceuticals    ATC1-4
# 1296     V20                                 SURGICAL DRESSINGS    ATC1-4

# %%
relaSource = 'ATC'
for i, c in subset.iterrows():
    start_time = time.time()
    classId = c['classId']
    url_s = f'https://rxnav.nlm.nih.gov/REST/rxclass/classMembers.json?classId={classId}&relaSource={relaSource}'
    json = pd.read_json(url_s)
    if (len(json) == 0): 
        print(f'RxClass # : {i}, found: 0 ............. SKIPPING')
        continue;
#     if (not json.has_key('drugMemberGroup')): 
#         continue
#     if (not json['drugMemberGroup'].has_key('drugMember')): 
#         continue

    item_top = json['drugMemberGroup']['drugMember']
    item = [{**x.pop('minConcept'), **c} for x in item_top]
    agg.extend(item)
    time_taken = round(time.time() - start_time, 2)
    number = len(json['drugMemberGroup']['drugMember'])
#     if (i%10==0):
    print(f'RxClass #: {i}, found: {number}, time taken: {time_taken}s')

    time.sleep(_wait)
# Out:
# RxClass #: 1000, found: 3, time taken: 0.72s
# RxClass #: 1001, found: 5, time taken: 0.45s
# RxClass #: 1002, found: 5, time taken: 0.49s
# RxClass #: 1003, found: 3, time taken: 0.44s
# RxClass #: 1004, found: 3, time taken: 0.49s
# RxClass #: 1005, found: 13, time taken: 0.48s
# RxClass # : 1006, found: 0 ............. SKIPPING
# RxClass #: 1007, found: 13, time taken: 0.43s
# RxClass #: 1008, found: 81, time taken: 0.52s
# RxClass #: 1009, found: 44, time taken: 0.5s
# RxClass #: 1010, found: 20, time taken: 0.48s
# RxClass #: 1011, found: 3, time taken: 0.45s
# RxClass #: 1012, found: 6, time taken: 0.45s
# RxClass #: 1013, found: 2, time taken: 0.45s
# RxClass #: 1014, found: 1, time taken: 0.48s
# RxClass #: 1015, found: 8, time taken: 0.48s
# RxClass #: 1016, found: 15, time taken: 0.49s
# RxClass #: 1017, found: 5, time taken: 0.45s
# RxClass #: 1018, found: 2, time taken: 0.49s
# RxClass #: 1019, found: 2, time taken: 0.49s
# RxClass #: 1020, found: 1, time taken: 0.45s
# RxClass #: 1021, found: 3, time taken: 0.48s
# RxClass #: 1022, found: 1, time taken: 0.45s
# RxClass #: 1023, found: 1, time taken: 0.63s
# RxClass #: 1024, found: 9, time taken: 0.43s
# RxClass #: 1025, found: 2, time taken: 0.44s
# RxClass #: 1026, found: 2, time taken: 0.45s
# RxClass #: 1027, found: 2, time taken: 0.45s
# RxClass # : 1028, found: 0 ............. SKIPPING
# RxClass #: 1029, found: 3, time taken: 0.43s
# RxClass #: 1030, found: 19, time taken: 0.48s
# RxClass #: 1031, found: 4, time taken: 0.45s
# RxClass #: 1032, found: 2, time taken: 0.44s
# RxClass #: 1033, found: 1, time taken: 0.49s
# RxClass #: 1034, found: 1, time taken: 0.44s
# RxClass #: 1035, found: 13, time taken: 0.46s
# RxClass #: 1036, found: 5, time taken: 0.49s
# RxClass #: 1037, found: 2, time taken: 0.44s
# RxClass #: 1038, found: 2, time taken: 0.46s
# RxClass #: 1039, found: 1, time taken: 0.48s
# RxClass #: 1040, found: 1, time taken: 0.51s
# RxClass #: 1041, found: 2, time taken: 0.47s
# RxClass #: 1042, found: 2, time taken: 0.46s
# RxClass #: 1043, found: 1, time taken: 0.48s
# RxClass #: 1044, found: 1, time taken: 0.5s
# RxClass #: 1045, found: 18, time taken: 0.5s
# RxClass #: 1046, found: 14, time taken: 0.48s
# RxClass #: 1047, found: 3, time taken: 0.45s
# RxClass #: 1048, found: 1, time taken: 0.44s
# RxClass #: 1049, found: 4, time taken: 0.5s
# RxClass #: 1050, found: 6, time taken: 0.49s
# RxClass #: 1051, found: 4, time taken: 0.5s
# RxClass #: 1052, found: 2, time taken: 0.44s
# RxClass #: 1053, found: 2, time taken: 0.48s
# RxClass #: 1054, found: 216, time taken: 0.6s
# RxClass #: 1055, found: 38, time taken: 0.48s
# RxClass #: 1056, found: 36, time taken: 0.45s
# RxClass #: 1057, found: 11, time taken: 0.45s
# RxClass #: 1058, found: 6, time taken: 0.45s
# RxClass #: 1059, found: 7, time taken: 0.48s
# RxClass #: 1060, found: 12, time taken: 0.49s
# RxClass #: 1061, found: 6, time taken: 0.45s
# RxClass #: 1062, found: 3, time taken: 0.49s
# RxClass #: 1063, found: 3, time taken: 0.45s
# RxClass #: 1064, found: 27, time taken: 0.51s
# RxClass #: 1065, found: 27, time taken: 0.44s
# RxClass #: 1066, found: 15, time taken: 0.45s
# RxClass #: 1067, found: 5, time taken: 0.44s
# RxClass #: 1068, found: 4, time taken: 0.47s
# RxClass #: 1069, found: 3, time taken: 0.48s
# RxClass #: 1070, found: 61, time taken: 0.52s
# RxClass #: 1071, found: 22, time taken: 0.45s
# RxClass #: 1072, found: 1, time taken: 0.46s
# RxClass #: 1073, found: 2, time taken: 0.44s
# RxClass #: 1074, found: 16, time taken: 0.45s
# RxClass # : 1075, found: 0 ............. SKIPPING
# RxClass #: 1076, found: 3, time taken: 0.48s
# RxClass # : 1077, found: 0 ............. SKIPPING
# RxClass #: 1078, found: 18, time taken: 0.48s
# RxClass #: 1079, found: 9, time taken: 0.45s
# RxClass #: 1080, found: 6, time taken: 0.44s
# RxClass #: 1081, found: 2, time taken: 0.48s
# RxClass #: 1082, found: 1, time taken: 0.46s
# RxClass #: 1083, found: 17, time taken: 0.5s
# RxClass #: 1084, found: 1, time taken: 0.45s
# RxClass #: 1085, found: 3, time taken: 0.45s
# RxClass #: 1086, found: 13, time taken: 0.48s
# RxClass # : 1087, found: 0 ............. SKIPPING
# RxClass #: 1088, found: 18, time taken: 0.44s
# RxClass #: 1089, found: 7, time taken: 0.43s
# RxClass # : 1090, found: 0 ............. SKIPPING
# RxClass #: 1091, found: 2, time taken: 0.44s
# RxClass #: 1092, found: 9, time taken: 0.45s
# RxClass #: 1093, found: 44, time taken: 0.48s
# RxClass #: 1094, found: 20, time taken: 0.45s
# RxClass #: 1095, found: 8, time taken: 0.46s
# RxClass #: 1096, found: 12, time taken: 0.48s
# RxClass #: 1097, found: 24, time taken: 0.47s
# RxClass #: 1098, found: 7, time taken: 0.49s
# RxClass #: 1099, found: 17, time taken: 0.49s
# RxClass # : 1100, found: 0 ............. SKIPPING
# RxClass # : 1101, found: 0 ............. SKIPPING
# RxClass # : 1102, found: 0 ............. SKIPPING
# RxClass # : 1103, found: 0 ............. SKIPPING
# RxClass #: 1104, found: 53, time taken: 0.44s
# RxClass #: 1105, found: 53, time taken: 0.48s
# RxClass #: 1106, found: 9, time taken: 0.49s
# RxClass #: 1107, found: 6, time taken: 0.44s
# RxClass #: 1108, found: 5, time taken: 0.44s
# RxClass #: 1109, found: 6, time taken: 0.45s
# RxClass #: 1110, found: 7, time taken: 0.44s
# RxClass # : 1111, found: 0 ............. SKIPPING
# RxClass #: 1112, found: 20, time taken: 0.44s
# RxClass #: 1113, found: 11, time taken: 0.49s
# RxClass #: 1114, found: 11, time taken: 0.48s
# RxClass #: 1115, found: 1, time taken: 0.49s
# RxClass #: 1116, found: 5, time taken: 0.49s
# RxClass #: 1117, found: 5, time taken: 0.5s
# RxClass #: 1118, found: 177, time taken: 0.65s
# RxClass #: 1119, found: 170, time taken: 0.6s
# RxClass #: 1120, found: 51, time taken: 0.49s
# RxClass #: 1121, found: 24, time taken: 0.45s
# RxClass #: 1122, found: 3, time taken: 0.48s
# RxClass #: 1123, found: 7, time taken: 0.45s
# RxClass #: 1124, found: 8, time taken: 0.48s
# RxClass #: 1125, found: 9, time taken: 0.44s
# RxClass #: 1126, found: 23, time taken: 0.45s
# RxClass #: 1127, found: 14, time taken: 0.46s
# RxClass # : 1128, found: 0 ............. SKIPPING
# RxClass #: 1129, found: 9, time taken: 0.45s
# RxClass #: 1130, found: 5, time taken: 0.48s
# RxClass # : 1131, found: 0 ............. SKIPPING
# RxClass #: 1132, found: 5, time taken: 0.43s
# RxClass # : 1133, found: 0 ............. SKIPPING
# RxClass #: 1134, found: 33, time taken: 0.48s
# RxClass #: 1135, found: 5, time taken: 0.48s
# RxClass #: 1136, found: 8, time taken: 0.48s
# RxClass #: 1137, found: 5, time taken: 0.46s
# RxClass #: 1138, found: 5, time taken: 0.45s
# RxClass #: 1139, found: 7, time taken: 0.48s
# RxClass #: 1140, found: 3, time taken: 0.52s
# RxClass #: 1141, found: 10, time taken: 0.49s
# RxClass #: 1142, found: 6, time taken: 0.46s
# RxClass #: 1143, found: 4, time taken: 0.48s
# RxClass #: 1144, found: 17, time taken: 0.45s
# RxClass #: 1145, found: 6, time taken: 0.48s
# RxClass #: 1146, found: 11, time taken: 0.49s
# RxClass #: 1147, found: 7, time taken: 0.44s
# RxClass #: 1148, found: 7, time taken: 0.46s
# RxClass #: 1149, found: 2, time taken: 0.48s
# RxClass #: 1150, found: 2, time taken: 0.49s
# RxClass # : 1151, found: 0 ............. SKIPPING
# RxClass #: 1152, found: 3, time taken: 0.45s
# RxClass #: 1153, found: 2, time taken: 0.44s
# RxClass #: 1154, found: 1, time taken: 0.43s
# RxClass #: 1155, found: 6, time taken: 0.43s
# RxClass #: 1156, found: 6, time taken: 0.46s
# RxClass #: 1157, found: 20, time taken: 0.43s
# RxClass #: 1158, found: 20, time taken: 0.43s
# RxClass #: 1159, found: 25, time taken: 0.46s
# RxClass #: 1160, found: 16, time taken: 0.49s
# RxClass #: 1161, found: 16, time taken: 0.48s
# RxClass #: 1162, found: 5, time taken: 0.49s
# RxClass #: 1163, found: 5, time taken: 0.49s
# RxClass # : 1164, found: 0 ............. SKIPPING
# RxClass # : 1165, found: 0 ............. SKIPPING
# RxClass #: 1166, found: 4, time taken: 0.44s
# RxClass #: 1167, found: 4, time taken: 0.48s
# RxClass # : 1168, found: 0 ............. SKIPPING
# RxClass #: 1169, found: 11, time taken: 0.48s
# RxClass #: 1170, found: 8, time taken: 0.48s
# RxClass #: 1171, found: 8, time taken: 0.48s
# RxClass #: 1172, found: 3, time taken: 0.44s
# RxClass #: 1173, found: 3, time taken: 0.44s
# RxClass # : 1174, found: 0 ............. SKIPPING
# RxClass # : 1175, found: 0 ............. SKIPPING
# RxClass # : 1176, found: 0 ............. SKIPPING
# RxClass #: 1177, found: 153, time taken: 0.53s
# RxClass # : 1178, found: 0 ............. SKIPPING
# RxClass # : 1179, found: 0 ............. SKIPPING
# RxClass # : 1180, found: 0 ............. SKIPPING
# RxClass #: 1181, found: 55, time taken: 0.49s
# RxClass #: 1182, found: 55, time taken: 0.46s
# RxClass #: 1183, found: 26, time taken: 0.45s
# RxClass #: 1184, found: 3, time taken: 0.49s
# RxClass #: 1185, found: 8, time taken: 0.45s
# RxClass #: 1186, found: 8, time taken: 0.48s
# RxClass #: 1187, found: 2, time taken: 0.45s
# RxClass #: 1188, found: 1, time taken: 0.45s
# RxClass # : 1189, found: 0 ............. SKIPPING
# RxClass # : 1190, found: 0 ............. SKIPPING
# RxClass #: 1191, found: 5, time taken: 0.48s
# RxClass #: 1192, found: 2, time taken: 0.44s
# RxClass #: 1193, found: 1, time taken: 0.43s
# RxClass #: 1194, found: 34, time taken: 0.44s
# RxClass # : 1195, found: 0 ............. SKIPPING
# RxClass #: 1196, found: 34, time taken: 0.48s
# RxClass #: 1197, found: 2, time taken: 0.44s
# RxClass # : 1198, found: 0 ............. SKIPPING
# RxClass #: 1199, found: 3, time taken: 0.47s
# RxClass #: 1200, found: 5, time taken: 0.48s
# RxClass #: 1201, found: 2, time taken: 0.43s
# RxClass #: 1202, found: 1, time taken: 0.48s
# RxClass #: 1203, found: 4, time taken: 0.44s
# RxClass #: 1204, found: 3, time taken: 0.45s
# RxClass #: 1205, found: 2, time taken: 0.45s
# RxClass #: 1206, found: 3, time taken: 0.48s
# RxClass # : 1207, found: 0 ............. SKIPPING
# RxClass #: 1208, found: 1, time taken: 0.48s
# RxClass #: 1209, found: 8, time taken: 0.45s
# RxClass #: 1210, found: 2, time taken: 0.45s
# RxClass # : 1211, found: 0 ............. SKIPPING
# RxClass # : 1212, found: 0 ............. SKIPPING
# RxClass # : 1213, found: 0 ............. SKIPPING
# RxClass # : 1214, found: 0 ............. SKIPPING
# RxClass # : 1215, found: 0 ............. SKIPPING
# RxClass #: 1216, found: 2, time taken: 0.44s
# RxClass # : 1217, found: 0 ............. SKIPPING
# RxClass # : 1218, found: 0 ............. SKIPPING
# RxClass #: 1219, found: 2, time taken: 0.48s
# RxClass # : 1220, found: 0 ............. SKIPPING
# RxClass # : 1221, found: 0 ............. SKIPPING
# RxClass # : 1222, found: 0 ............. SKIPPING
# RxClass # : 1223, found: 0 ............. SKIPPING
# RxClass # : 1224, found: 0 ............. SKIPPING
# RxClass # : 1225, found: 0 ............. SKIPPING
# RxClass # : 1226, found: 0 ............. SKIPPING
# RxClass # : 1227, found: 0 ............. SKIPPING
# RxClass # : 1228, found: 0 ............. SKIPPING
# RxClass # : 1229, found: 0 ............. SKIPPING
# RxClass # : 1230, found: 0 ............. SKIPPING
# RxClass # : 1231, found: 0 ............. SKIPPING
# RxClass # : 1232, found: 0 ............. SKIPPING
# RxClass # : 1233, found: 0 ............. SKIPPING
# RxClass # : 1234, found: 0 ............. SKIPPING
# RxClass # : 1235, found: 0 ............. SKIPPING
# RxClass # : 1236, found: 0 ............. SKIPPING
# RxClass # : 1237, found: 0 ............. SKIPPING
# RxClass #: 1238, found: 30, time taken: 0.48s
# RxClass #: 1239, found: 21, time taken: 0.49s
# RxClass #: 1240, found: 3, time taken: 0.44s
# RxClass #: 1241, found: 11, time taken: 0.44s
# RxClass #: 1242, found: 5, time taken: 0.44s
# RxClass #: 1243, found: 2, time taken: 0.48s
# RxClass # : 1244, found: 0 ............. SKIPPING
# RxClass # : 1245, found: 0 ............. SKIPPING
# RxClass #: 1246, found: 8, time taken: 0.44s
# RxClass #: 1247, found: 7, time taken: 0.48s
# RxClass #: 1248, found: 1, time taken: 0.48s
# RxClass # : 1249, found: 0 ............. SKIPPING
# RxClass #: 1250, found: 1, time taken: 0.44s
# RxClass #: 1251, found: 1, time taken: 0.44s
# RxClass #: 1252, found: 30, time taken: 0.48s
# RxClass #: 1253, found: 6, time taken: 0.48s
# RxClass #: 1254, found: 2, time taken: 0.49s
# RxClass #: 1255, found: 1, time taken: 0.45s
# RxClass #: 1256, found: 3, time taken: 0.44s
# RxClass # : 1257, found: 0 ............. SKIPPING
# RxClass # : 1258, found: 0 ............. SKIPPING
# RxClass #: 1259, found: 3, time taken: 0.44s
# RxClass # : 1260, found: 0 ............. SKIPPING
# RxClass #: 1261, found: 3, time taken: 0.48s
# RxClass #: 1262, found: 2, time taken: 0.47s
# RxClass #: 1263, found: 1, time taken: 0.45s
# RxClass #: 1264, found: 1, time taken: 0.43s
# RxClass # : 1265, found: 0 ............. SKIPPING
# RxClass #: 1266, found: 1, time taken: 0.44s
# RxClass # : 1267, found: 0 ............. SKIPPING
# RxClass # : 1268, found: 0 ............. SKIPPING
# RxClass #: 1269, found: 1, time taken: 0.43s
# RxClass #: 1270, found: 3, time taken: 0.48s
# RxClass #: 1271, found: 3, time taken: 0.49s
# RxClass #: 1272, found: 3, time taken: 0.45s
# RxClass #: 1273, found: 1, time taken: 0.44s
# RxClass #: 1274, found: 1, time taken: 0.49s
# RxClass #: 1275, found: 1, time taken: 0.51s
# RxClass #: 1276, found: 1, time taken: 0.43s
# RxClass # : 1277, found: 0 ............. SKIPPING
# RxClass # : 1278, found: 0 ............. SKIPPING
# RxClass #: 1279, found: 1, time taken: 0.47s
# RxClass #: 1280, found: 10, time taken: 0.49s
# RxClass #: 1281, found: 2, time taken: 0.45s
# RxClass #: 1282, found: 1, time taken: 0.48s
# RxClass #: 1283, found: 7, time taken: 0.46s
# RxClass #: 1284, found: 1, time taken: 0.49s
# RxClass # : 1285, found: 0 ............. SKIPPING
# RxClass #: 1286, found: 1, time taken: 0.44s
# RxClass #: 1287, found: 6, time taken: 0.47s
# RxClass # : 1288, found: 0 ............. SKIPPING
# RxClass # : 1289, found: 0 ............. SKIPPING
# RxClass # : 1290, found: 0 ............. SKIPPING
# RxClass #: 1291, found: 1, time taken: 0.47s
# RxClass #: 1292, found: 1, time taken: 0.5s
# RxClass #: 1293, found: 5, time taken: 0.51s
# RxClass #: 1294, found: 3, time taken: 0.48s
# RxClass #: 1295, found: 2, time taken: 0.44s
# RxClass # : 1296, found: 0 ............. SKIPPING

# %%
agg_df = pd.DataFrame(agg)
print(list(agg_df))
agg_df
# Out:
# ['rxcui', 'name', 'tty', 'classId', 'className', 'classType']
#          rxcui                      name  tty classId  \
# 0      1000082               alcaftadine   IN       0
# 1      1000581               trichlorfon   IN       0
# 2         1001                antipyrine   IN       0
# 3      1001472  dutasteride / tamsulosin  MIN       0
# 4      1002293   formoterol / mometasone  MIN       0
# ...        ...                       ...  ...     ...
# 16446  2053281          iobenguane I-131  PIN   V10XA
# 16447   234449    iodine-131-tositumomab  PIN   V10XA
# 16448    91535        sodium iodide I131  PIN   V10XA
# 16449  1999335  lutetium Lu 177 dotatate  PIN   V10XX
# 16450    91559      sodium phosphate P32  PIN   V10XX
#
#                                       className classType
# 0      Anatomical Therapeutic Chemical (ATC1-4)    ATC1-4
# 1      Anatomical Therapeutic Chemical (ATC1-4)    ATC1-4
# 2      Anatomical Therapeutic Chemical (ATC1-4)    ATC1-4
# 3      Anatomical Therapeutic Chemical (ATC1-4)    ATC1-4
# 4      Anatomical Therapeutic Chemical (ATC1-4)    ATC1-4
# ...                                         ...       ...
# 16446                   Iodine (131I) compounds    ATC1-4
# 16447                   Iodine (131I) compounds    ATC1-4
# 16448                   Iodine (131I) compounds    ATC1-4
# 16449  Various therapeutic radiopharmaceuticals    ATC1-4
# 16450  Various therapeutic radiopharmaceuticals    ATC1-4
#
# [16451 rows x 6 columns]

# %%
agg_df.to_csv(_class_output_csv_path)

# %%
out = agg_df['className'].value_counts().reset_index(name="counts")
out.head(20)
# Out:
#                                          index  counts
# 0     Anatomical Therapeutic Chemical (ATC1-4)    2864
# 1                               NERVOUS SYSTEM     449
# 2              ALIMENTARY TRACT AND METABOLISM     408
# 3   ANTINEOPLASTIC AND IMMUNOMODULATING AGENTS     347
# 4              ANTIINFECTIVES FOR SYSTEMIC USE     338
# 5                        CARDIOVASCULAR SYSTEM     333
# 6                              DERMATOLOGICALS     250
# 7                        ANTINEOPLASTIC AGENTS     222
# 8                           RESPIRATORY SYSTEM     217
# 9              ANTIBACTERIALS FOR SYSTEMIC USE     189
# 10                              SENSORY ORGANS     177
# 11                           OPHTHALMOLOGICALS     170
# 12              BLOOD AND BLOOD FORMING ORGANS     163
# 13      GENITO URINARY SYSTEM AND SEX HORMONES     161
# 14                                     VARIOUS     153
# 15                          IMMUNOSUPPRESSANTS     138
# 16                     MUSCULO-SKELETAL SYSTEM     134
# 17                               PSYCHOLEPTICS     134
# 18                       ANTITHROMBOTIC AGENTS     116
# 19              ALL OTHER THERAPEUTIC PRODUCTS     110
